# %% [markdown]
# ## Бонусное задание: word2vec на PyTorch
#
# Как вы уже могли заметить, идея, лежащая в основе [word2vec](https://arxiv.org/pdf/1310.4546), достаточно общая. В данном задании вы реализуете его самостоятельно.
#
# Дисклеймер: не стоит удивляться тому, что реализация от `gensim` (или аналоги) обучается быстрее и работает точнее. Она использует множество доработок и ускорений, а также достаточно эффективный код. Ваша задача добиться промежуточных результатов за разумное время.
#
# P.s. Как ни странно, GPU в этом задании нам не потребуется.

# %% [markdown]
# __Requirements:__ if you're running locally, in the selected environment run the following command:
#
# ```pip install --upgrade nltk bokeh umap-learn```

# %%
#!pip install --upgrade nltk bokeh umap-learn

# %%
import itertools
import random
import string
from collections import Counter
from itertools import chain

import matplotlib.pyplot as plt
import numpy as np
import torch
import torch.autograd as autograd
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim
import umap
from IPython.display import clear_output
from matplotlib import pyplot as plt
from nltk.tokenize import WordPunctTokenizer
from torch.optim.lr_scheduler import ReduceLROnPlateau, StepLR
from tqdm.auto import tqdm as tqdma
# Out:
# WARNING:tensorflow:From c:\Users\VIKTOR\AppData\Local\Programs\Python\Python310\lib\site-packages\keras\src\losses.py:2976: The name tf.losses.sparse_softmax_cross_entropy is deprecated. Please use tf.compat.v1.losses.sparse_softmax_cross_entropy instead.

# %%
# download the data:
# !wget https://www.dropbox.com/s/obaitrix9jyu84r/quora.txt?dl=1 -O ./quora.txt -nc
# alternative download link: https://yadi.sk/i/BPQrUu1NaTduEw
# Out:
# "wget" �� ���� ����७��� ��� ���譥�
# ��������, �ᯮ��塞�� �ணࠬ��� ��� ������ 䠩���.

# %%
data = list(open("./quora.txt", encoding="utf-8"))
data[50]
# Out:
# "What TV shows or books help you read people's body language?\n"

# %% [markdown]
# Токенизация – первый шаг.
# Тексты, с которыми мы работаем, включают в себя пунктуацию, смайлики и прочие нестандартные токены, так что простой `str.split` не подойдет.
#
# Обратимся к `nltk` - библиотеку, нашла широкое применеие в области NLP.

# %%
tokenizer = WordPunctTokenizer()

print(tokenizer.tokenize(data[50]))
# Out:
# ['What', 'TV', 'shows', 'or', 'books', 'help', 'you', 'read', 'people', "'", 's', 'body', 'language', '?']

# %%
data_tok = [
    tokenizer.tokenize(
        line.translate(str.maketrans("", "", string.punctuation)).lower()
    )
    for line in data
]
data_tok = [x for x in data_tok if len(x) >= 3]

# %%
data_tok
# Out:
# [['can',
#   'i',
#   'get',
#   'back',
#   'with',
#   'my',
#   'ex',
#   'even',
#   'though',
#   'she',
#   'is',
#   'pregnant',
#   'with',
#   'another',
#   'guys',
#   'baby'],
#  ['what',
#   'are',
#   'some',
#   'ways',
#   'to',
#   'overcome',
#   'a',
#   'fast',
#   'food',
#   'addiction'],
#  ['who',
#   'were',
#   'the',
#   'great',
#   'chinese',
#   'soldiers',
#   'and',
#   'leaders',
#   'who',
#   'fought',
#   'in',
#   'ww2'],
#  ['what', 'are', 'zip', 'codes', 'in', 'the', 'bay', 'area'],
#  ['why',
#   'was',
#   'george',
#   'rr',
#   'martin',
#   'critical',
#   'of',
#   'jk',
#   'rowling',
#   'after',
#   'losing',
#   'the',
#   'hugo',
#   'award'],
#  ['what', 'can', 'i', 'do', 'to', 'improve', 'my', 'immune', 'system'],
#  ['how', 'is', 'your', 'relationship', 'with', 'your', 'mother', 'in', 'law'],
#  ['how', 'does', 'one', 'get', 'free', 'psn', 'codesvita', 'codes'],
#  ['what', 'is', 'your', 'review', 'of', 'osquery'],
#  ['how', 'can', 'i', 'look', 'smart', 'and', 'act', 'smart'],
#  ['which',
#   'brand',
#   'should',
#   'go',
#   'with',
#   'the',
#   'gtx',
#   '960',
#   'graphic',
#   'card',
#   'msi',
#   'zotac',
#   'or',
#   'asus'],
#  ['what', 'is', 'the', 'zip', 'code', 'of', 'india'],
#  ['as',
#   'an',
#   'indian',
#   'doctor',
#   'practicing',
#   'in',
#   'my',
#   'own',
#   'private',
#   'clinic',
#   'how',
#   'can',
#   'i',
#   'earn',
#   'more',
#   'what',
#   'other',
#   'sources',
#   'of',
#   'income',
#   'can',
#   'i',
#   'use'],
#  ['is',
#   'windows',
#   'the',
#   'only',
#   'os',
#   'that',
#   'is',
#   'not',
#   'based',
#   'on',
#   'unix',
#   'or',
#   'linux'],
#  ['how', 'can', 'i', 'avoid', 'using', 'facebook'],
#  ['how', 'do', 'you', 'get', 'a', 'norton', 'security', 'renewal', 'code'],
#  ['does',
#   'emc',
#   'plan',
#   'a',
#   'lightweight',
#   'web',
#   'client',
#   'for',
#   'documentum'],
#  ['where', 'is', 'the', 'strangest', 'place', 'youve', 'ever', 'masturbated'],
#  ['tamil',
#   'nadu',
#   'india',
#   'what',
#   'can',
#   'we',
#   'learn',
#   'from',
#   'ex',
#   'cm',
#   'jjayalalitha'],
#  ['which',
#   'car',
#   'should',
#   'i',
#   'buy',
#   'out',
#   'of',
#   'tiago',
#   'kwid',
#   'figo',
#   'datsun',
#   'or',
#   'any',
#   'other'],
#  ['who', 'discovered', 'plate', 'tectonics', 'and', 'how'],
#  ['is',
#   'the',
#   'earth',
#   'the',
#   'only',
#   'planet',
#   'that',
#   'has',
#   'life',
#   'on',
#   'it'],
#  ['how', 'can', 'i', 'get', 'a', 'ride', 'on', 'a', 'civilian', 'c130'],
#  ['what', 'does', 'entertainment', 'mean', 'for', 'you'],
#  ['how',
#   'is',
#   'the',
#   'experience',
#   'to',
#   'be',
#   'an',
#   'extra',
#   'on',
#   'the',
#   'show',
#   'how',
#   'i',
#   'met',
#   'your',
#   'mother'],
#  ['will',
#   'windows',
#   'run',
#   'well',
#   'enough',
#   'to',
#   'use',
#   'excel',
#   'and',
#   'outlook',
#   'in',
#   'a',
#   'vm',
#   'on',
#   'the',
#   'new',
#   '2015',
#   'macbook'],
#  ['is',
#   'it',
#   'true',
#   'that',
#   'ancient',
#   'china',
#   'had',
#   'no',
#   'glass',
#   'or',
#   'was',
#   'it',
#   'no',
#   'clear',
#   'glass',
#   'or',
#   'not'],
#  ['what', 'is', 'your', 'review', 'of', 'ipad', 'mini', '2'],
#  ['what', 'is', 'the', 'purpose', 'of', 'steam', 'turbine'],
#  ['when',
#   'do',
#   'you',
#   'really',
#   'need',
#   'to',
#   'create',
#   'an',
#   'abstract',
#   'class'],
#  ['how', 'are', 'dalmatian', 'dogs', 'like', 'as', 'pets'],
#  ['are',
#   'drivers',
#   'within',
#   'rich',
#   'countries',
#   'less',
#   'likely',
#   'to',
#   'slow',
#   'down',
#   'when',
#   'they',
#   'see',
#   'a',
#   'drivers',
#   'turn',
#   'signal'],
#  ['are', 'asian', 'girls', 'attracted', 'to', 'black', 'guys'],
#  ['from',
#   'where',
#   'can',
#   'i',
#   'buy',
#   'castor',
#   'oil',
#   'for',
#   'hair',
#   'in',
#   'mumbai'],
#  ['does', 'cvs', 'still', 'develop', 'film', 'why', 'or', 'why', 'not'],
#  ['can', 'china', 'always', 'print', 'money'],
#  ['what', 'is', 'fake', 'software'],
#  ['how', 'do', 'students', 'at', 'iit', 'get', 'foreign', 'internships'],
#  ['how', 'do', 'i', 'find', 'my', 'lifes', 'goal'],
#  ['what', 'are', 'the', 'upcoming', 'mobiles'],
#  ['what', 'is', 'the', 'chemical', 'formula', 'for', 'hydrochloric', 'acid'],
#  ['which',
#   'is',
#   'the',
#   'biggest',
#   'disneyland',
#   'in',
#   'the',
#   'world',
#   'what',
#   'is',
#   'the',
#   'best',
#   'way',
#   'to',
#   'get',
#   'entrance',
#   'tickets',
#   'for',
#   'it'],
#  ['how', 'does', 'the', 'finance', 'credit', 'score', 'work'],
#  ['how', 'do', 'i', 'meet', 'foreign', 'guys', 'in', 'hong', 'kong'],
#  ['is', 'the', 'atm', 'business', 'still', 'viable'],
#  ['how',
#   'can',
#   'i',
#   'learn',
#   'to',
#   'speak',
#   'english',
#   'well',
#   'in',
#   'nonenglish',
#   'environment'],
#  ['can',
#   'a',
#   'high',
#   'school',
#   'student',
#   'get',
#   'an',
#   'internship',
#   'at',
#   'goldman',
#   'sachs'],
#  ['who', 'are', 'the', 'top', 'business', 'coaches', 'in', 'australia'],
#  ['why', 'do', 'girls', 'wait', 'for', 'boys', 'to', 'propose'],
#  ['should',
#   'cricket',
#   'be',
#   'our',
#   'national',
#   'sport',
#   'and',
#   'not',
#   'hockey'],
#  ['what',
#   'tv',
#   'shows',
#   'or',
#   'books',
#   'help',
#   'you',
#   'read',
#   'peoples',
#   'body',
#   'language'],
#  ['i',
#   'see',
#   'this',
#   'cute',
#   'girl',
#   'around',
#   'my',
#   'college',
#   'im',
#   'too',
#   'shy',
#   'to',
#   'approach',
#   'her',
#   'is',
#   'it',
#   'acceptable',
#   'to',
#   'leave',
#   'her',
#   'a',
#   'note',
#   'with',
#   'my',
#   'feelings',
#   'and',
#   'number'],
#  ['what',
#   'schools',
#   'can',
#   'i',
#   'apply',
#   'for',
#   'with',
#   'a',
#   'gre',
#   'score',
#   'of',
#   'q165',
#   'v153'],
#  ['what',
#   'is',
#   'the',
#   'solution',
#   'for',
#   'this',
#   'quickbooks',
#   'error',
#   '12031'],
#  ['do',
#   'you',
#   'think',
#   'the',
#   'aap',
#   'will',
#   'fulfill',
#   'the',
#   'promises',
#   'they',
#   'mentioned',
#   'in',
#   'their',
#   'manifesto',
#   'why',
#   'and',
#   'how'],
#  ['what',
#   'are',
#   'all',
#   'the',
#   'pros',
#   'and',
#   'cons',
#   'of',
#   'having',
#   'dual',
#   'citizenship'],
#  ['can',
#   'someone',
#   'translate',
#   'this',
#   'one',
#   'from',
#   'italian',
#   'or',
#   'latin'],
#  ['what', 'is', '“', 'directive', '”'],
#  ['what', 'is', 'the', 'density', 'and', 'volume', 'of', 'black', 'hole'],
#  ['what', 'does', 'las', 'vegas', 'mean'],
#  ['is', 'it', 'possible', 'to', 'lick', 'a', 'toad', 'and', 'get', 'high'],
#  ['who', 'nominates', 'the', 'president', 'of', 'india'],
#  ['how',
#   'does',
#   'linkedin',
#   'work',
#   'im',
#   'getting',
#   'connections',
#   'so',
#   'now',
#   'what',
#   'how',
#   'do',
#   'i',
#   'find',
#   'a',
#   'job'],
#  ['how', 'can', 'i', 'record', 'a', 'facetime', 'call', 'on', 'a', 'mac'],
#  ['what', 'are', 'the', 'application', 'of', 'binary', 'search', 'trees'],
#  ['why',
#   'do',
#   'symptoms',
#   'persist',
#   'even',
#   'when',
#   'you',
#   'know',
#   'they',
#   'are',
#   'psychosomatic'],
#  ['what', 'are', 'the', 'best', 'digital', 'marketing', 'agencies'],
#  ['why',
#   'is',
#   'my',
#   '128gb',
#   'micro',
#   'sd',
#   'cards',
#   'capacity',
#   'reduced',
#   'to',
#   '119gb',
#   'in',
#   'linux',
#   'it',
#   'showed',
#   '128gb',
#   'but',
#   'now',
#   'it',
#   'only',
#   'shows',
#   'said',
#   'capacity',
#   'even',
#   'in',
#   'ubuntu'],
#  ['did', 'you', 'visit', 'vietnam'],
#  ['are', 'there', 'any', 'nobel', 'prize', 'winners', 'on', 'quora'],
#  ['what', 'are', 'the', 'alternatives', 'to', 'walkme'],
#  ['is', 'love', 'the', 'most', 'precious', 'thing', 'in', 'life'],
#  ['how',
#   'can',
#   'i',
#   'download',
#   'cool',
#   'stuff',
#   'on',
#   'my',
#   'iphone',
#   'like',
#   'they',
#   'have',
#   'on',
#   'cydia',
#   'cause',
#   'im',
#   'not',
#   'jailbroken'],
#  ['how', 'do', 'i', 'start', 'investing', 'in', 'stocks', 'with', '100', '€'],
#  ['what',
#   'is',
#   'quantitative',
#   'analysis',
#   'in',
#   'finance',
#   'how',
#   'is',
#   'it',
#   'applied'],
#  ['what',
#   'is',
#   'the',
#   'process',
#   'to',
#   'be',
#   'a',
#   'guest',
#   'speaker',
#   'on',
#   'npr'],
#  ['we',
#   'cant',
#   'see',
#   'the',
#   'universe',
#   'beyond',
#   'our',
#   'time',
#   'and',
#   'mind',
#   'why'],
#  ['what', 'does', 'a', 'programmer', 'do', 'at', 'their', 'job'],
#  ['why',
#   'does',
#   'china',
#   'not',
#   'want',
#   'to',
#   'be',
#   'seen',
#   'as',
#   'a',
#   'superpower',
#   'while',
#   'india',
#   'is',
#   'very',
#   'keen',
#   'on',
#   'being',
#   'seen',
#   'as',
#   'one'],
#  ['for',
#   'the',
#   'g5',
#   'building',
#   'what',
#   'is',
#   'the',
#   'minimum',
#   'steel',
#   'section',
#   'used',
#   'as',
#   'bracings',
#   'in',
#   'staad'],
#  ['what',
#   'are',
#   'some',
#   'of',
#   'the',
#   'most',
#   'epic',
#   'photos',
#   'ever',
#   'taken'],
#  ['why',
#   'do',
#   'our',
#   'feet',
#   'and',
#   'other',
#   'body',
#   'parts',
#   'fall',
#   'asleep'],
#  ['who', 'are', 'the', 'true', 'muslims', 'shia', 'or', 'sunni'],
#  ['how',
#   'much',
#   'can',
#   'be',
#   'served',
#   'with',
#   'a',
#   'liter',
#   'bottle',
#   'of',
#   'vodka'],
#  ['why',
#   'do',
#   'people',
#   'pay',
#   'for',
#   'netflix',
#   'when',
#   'they',
#   'can',
#   'stream',
#   'online',
#   'for',
#   'free',
#   'and',
#   'in',
#   'better',
#   'quality'],
#  ['is', 'euthanasia', 'ever', 'morally', 'permissible'],
#  ['is',
#   'it',
#   'worth',
#   'it',
#   'to',
#   'loose',
#   'your',
#   'virginity',
#   'as',
#   'a',
#   'freshman',
#   'in',
#   'high',
#   'school'],
#  ['what',
#   'do',
#   'you',
#   'think',
#   'about',
#   'rbi',
#   'directive',
#   'of',
#   'allowing',
#   'only',
#   'once',
#   'to',
#   'deposit',
#   'old',
#   'notes',
#   'in',
#   'bank',
#   'account'],
#  ['what',
#   'hill',
#   'stationpicnic',
#   'spot',
#   'is',
#   'of',
#   'equal',
#   'distance',
#   'from',
#   'bangalore',
#   'and',
#   'pune'],
#  ['how', 'can', 'i', 'make', 'myself', 'read', 'an', 'entire', 'book'],
#  ['how', 'do', 'you', 'become', 'chancellor', 'of', 'a', 'university'],
#  ['if', 'trump', 'wins', 'will', 'there', 'be', 'a', 'nuclear', 'war'],
#  ['how',
#   'do',
#   'i',
#   'prevent',
#   'users',
#   'on',
#   'the',
#   'same',
#   'netflix',
#   'account',
#   'from',
#   'seeing',
#   'my',
#   'profile'],
#  ['what', 'was', 'osama', 'bin', 'laden', 'like', 'as', 'a', 'person'],
#  ['which',
#   'was',
#   'the',
#   'best',
#   'porn',
#   'video',
#   'you',
#   'have',
#   'ever',
#   'seen',
#   'why',
#   'was',
#   'that',
#   'the',
#   'best',
#   'one'],
#  ['how', 'can', 'i', 'get', 'sbi', 'transaction', 'id'],
#  ['what',
#   'is',
#   'a',
#   'good',
#   'way',
#   'to',
#   'start',
#   'studying',
#   'for',
#   'a',
#   'career',
#   'in',
#   'cybersecurity'],
#  ['what', 'are', 'the', 'components', 'of', 'fitness'],
#  ['what',
#   'is',
#   'the',
#   'good',
#   'approach',
#   'to',
#   'implement',
#   'rest',
#   'api',
#   'either',
#   'to',
#   'go',
#   'with',
#   'http',
#   'status',
#   'codes',
#   'or',
#   'creating',
#   'custom',
#   'error',
#   'field',
#   'by',
#   'always',
#   'returning',
#   '200'],
#  ['what', 'is', 'the', 'iupac', 'name', 'of', 'tertbutyl', 'chloride'],
#  ['how', 'similar', 'are', 'soylent', 'and', 'ensure', 'nutritionally'],
#  ['what', 'is', 'the', 'future', 'of', 'sociology', 'education'],
#  ['how', 'can', 'i', 'choose', 'to', 'make', 'the', 'right', 'decision'],
#  ['what', 'does', 'void', 'p', 'p', 'mean', 'in', 'c'],
#  ['can',
#   'you',
#   'take',
#   'mucinex',
#   'if',
#   'you',
#   'have',
#   'high',
#   'blood',
#   'pressure'],
#  ['which',
#   'universities',
#   'have',
#   'good',
#   'phd',
#   'programs',
#   'in',
#   'image',
#   'processing',
#   'and',
#   'computer',
#   'vision'],
#  ['what', 'is', 'your', 'favorite', 'moment', 'with', 'quora'],
#  ['how', 'can', 'i', 'make', 'studying', 'more', 'interesting'],
#  ['how',
#   'are',
#   'the',
#   'balloons',
#   'designed',
#   'and',
#   'built',
#   'for',
#   'the',
#   'macys',
#   'thanksgiving',
#   'day',
#   'parade'],
#  ['what', 'is', 'the', 'significance', 'of', 'bicsi', 'cec'],
#  ['how', 'do', 'you', 'set', 'a', 'honeywell', 'thermostat'],
#  ['which',
#   'needs',
#   'more',
#   'power',
#   'in',
#   'a',
#   'laptop',
#   'gaming',
#   'or',
#   'video',
#   'editing'],
#  ['what',
#   'is',
#   'the',
#   'meaning',
#   'of',
#   'a',
#   'hindi',
#   'word',
#   'ब',
#   'े',
#   'दब',
#   'ी'],
#  ['what',
#   'are',
#   'some',
#   'good',
#   'books',
#   'to',
#   'learn',
#   'data',
#   'structures',
#   'and',
#   'algorithms',
#   'for',
#   'a',
#   'beginner'],
#  ['what',
#   'are',
#   'some',
#   'of',
#   'the',
#   'best',
#   'answers',
#   'written',
#   'on',
#   'women',
#   'empowerment'],
#  ['what',
#   'makes',
#   'isis',
#   'attractive',
#   'for',
#   'the',
#   'youth',
#   'living',
#   'in',
#   'the',
#   'western',
#   'countries'],
#  ['what', 'is', 'adding', '12', 'to', '14', 'equals'],
#  ['how',
#   'do',
#   'i',
#   'differentiate',
#   'between',
#   'human',
#   'and',
#   'animal',
#   'blood'],
#  ['what', 'is', 'the', 'difference', 'between', 'watts', 'and', 'lumens'],
#  ['how', 'does', 'getting', 'a', 'divorce', 'change', 'your', 'life'],
#  ['what', 'happens', 'to', 'my', 'stock', 'options', 'when', 'i', 'quit'],
#  ['do', 'fetuses', 'suffer', 'during', 'an', 'abortion'],
#  ['chefs',
#   'do',
#   'you',
#   'write',
#   'your',
#   'own',
#   'menus',
#   'for',
#   'cooking',
#   'at',
#   'home',
#   'i',
#   'made',
#   'a',
#   'static',
#   'menu',
#   'with',
#   'three',
#   'cuisines',
#   'do',
#   'you',
#   'have',
#   'tips',
#   'for',
#   'writing',
#   'menus'],
#  ['how', 'do', 'i', 'make', 'best', 'use', 'of', 'ieee'],
#  ['what', 'are', 'the', 'uga', 'sat', 'score', 'requirements'],
#  ['i',
#   'get',
#   'aroused',
#   'when',
#   'i',
#   'see',
#   'movie',
#   'scene',
#   'where',
#   'slave',
#   'get',
#   'whipped',
#   'and',
#   'get',
#   'excited',
#   'when',
#   'see',
#   'red',
#   'strips',
#   'on',
#   'their',
#   'back',
#   'is',
#   'it',
#   'normal'],
#  ['what',
#   'distinguishes',
#   'litigation',
#   'from',
#   'other',
#   'forms',
#   'of',
#   'legal',
#   'intervention'],
#  ['are', 'all', 'good', 'deeds', 'inherently', 'selfish'],
#  ['which',
#   'are',
#   'some',
#   'of',
#   'the',
#   'best',
#   'horror',
#   'hollywood',
#   'movies',
#   'to',
#   'watch'],
#  ['in',
#   'the',
#   'case',
#   'of',
#   'a',
#   'power',
#   'plant',
#   'what',
#   'is',
#   'the',
#   'difference',
#   'between',
#   'a',
#   'synchronous',
#   'generator',
#   'and',
#   'an',
#   'asynchronous',
#   'generator',
#   'which',
#   'is',
#   'preferred',
#   'and',
#   'why'],
#  ['if',
#   'the',
#   'education',
#   'system',
#   'in',
#   'the',
#   'us',
#   'is',
#   'really',
#   'bad',
#   'why',
#   'are',
#   'people',
#   'all',
#   'over',
#   'the',
#   'world',
#   'coming',
#   'to',
#   'the',
#   'us',
#   'for',
#   'education'],
#  ['what', 'is', 'the', 'scope', 'of', 'material', 'science', 'engineering'],
#  ['as',
#   'a',
#   'practising',
#   'financial',
#   'planner',
#   'in',
#   'india',
#   'how',
#   'much',
#   'have',
#   'you',
#   'been',
#   'able',
#   'to',
#   'make',
#   'in',
#   'terms',
#   'of',
#   'advisory',
#   'fee',
#   'alone'],
#  ['which',
#   'is',
#   'the',
#   'best',
#   'digital',
#   'marketing',
#   'company',
#   'in',
#   'pune'],
#  ['what',
#   'stats',
#   'prove',
#   'that',
#   'after',
#   'school',
#   'activities',
#   'combat',
#   'the',
#   'achievement',
#   'gap',
#   'and',
#   'promote',
#   'college',
#   'admissions'],
#  ['how', 'do', 'i', 'pronounce', 'òló'],
#  ['i',
#   'have',
#   'not',
#   'paid',
#   'amount',
#   'for',
#   'taking',
#   'parents',
#   'in',
#   'tu',
#   'convocation',
#   'can',
#   'i',
#   'take',
#   'them'],
#  ['opportunities', 'after', 'phd', 'in', 'sweden', 'in', 'medicine'],
#  ['what',
#   'are',
#   'the',
#   'automobile',
#   'projects',
#   'related',
#   'to',
#   'design',
#   'and',
#   'analysis',
#   'of',
#   'automobile',
#   'part'],
#  ['what',
#   'is',
#   'the',
#   'basic',
#   'computer',
#   'knowledge',
#   'that',
#   'everyone',
#   'should',
#   'know'],
#  ['what',
#   'are',
#   'the',
#   'most',
#   'well',
#   'known',
#   'startup',
#   'or',
#   'venture',
#   'capital',
#   'firms'],
#  ['which',
#   'are',
#   'the',
#   'best',
#   'colleges',
#   'in',
#   'usa',
#   'for',
#   'aerospace',
#   'engineering'],
#  ['why',
#   'are',
#   'some',
#   'items',
#   'made',
#   'of',
#   'wool',
#   'so',
#   'itchy',
#   'but',
#   'others',
#   'soft'],
#  ['how',
#   'do',
#   'people',
#   'get',
#   'obese',
#   'do',
#   'they',
#   'eat',
#   'a',
#   'lot',
#   'more',
#   'than',
#   'the',
#   'average',
#   'person'],
#  ['how',
#   'do',
#   'you',
#   'get',
#   'wireless',
#   'internet',
#   'for',
#   'a',
#   'desktop',
#   'computer'],
#  ['what', 'is', 'your', 'favorite', 'song', 'at', 'the', 'moment'],
#  ['can', 'cancer', 'be', 'cured', 'by', 'healing'],
#  ['what', 'kind', 'of', 'pens', 'write', 'much', 'better'],
#  ['why', 'men', 'dont', 'take', 'divorced', 'woman', 'seriously'],
#  ['can', 'we', 'trust', 'chegg', 'did', 'anybody', 'got', 'paid'],
#  ['which',
#   'is',
#   'better',
#   '5',
#   'gb',
#   'ram',
#   'with',
#   'core',
#   'i3',
#   'or',
#   '2',
#   'gb',
#   'ram',
#   'with',
#   'i5',
#   'processor',
#   'for',
#   'android',
#   'studio'],
#  ['have', 'you', 'ever', 'changed', 'a', 'deeply', 'held', 'opinion'],
#  ['what', 'is', 'depersonalization', 'disorder'],
#  ['why',
#   'cant',
#   'you',
#   'use',
#   'wifi',
#   'while',
#   'running',
#   'a',
#   'wifi',
#   'hotspot'],
#  ['what', 'is', 'the', 'best', 'lg', 'g3', 'app'],
#  ['what',
#   'are',
#   'the',
#   'expectations',
#   'of',
#   'indian',
#   'women',
#   'from',
#   'their',
#   'partners',
#   'during',
#   'sex'],
#  ['what',
#   'is',
#   'your',
#   'review',
#   'of',
#   'the',
#   'story',
#   'of',
#   'my',
#   'experiments',
#   'with',
#   'truth',
#   'book',
#   'by',
#   'mahatma',
#   'gandhi'],
#  ['what', 'is', 'the', 'most', 'beautiful', 'scandinavian', 'country'],
#  ['where', 'can', 'i', 'download', 'a', 'free', 'ebook', 'in', 'french'],
#  ['what', 'is', 'something', 'that', 'you', 'know', 'that', 'i', 'dont'],
#  ['how',
#   'did',
#   'the',
#   'academy',
#   'awards',
#   'come',
#   'to',
#   'be',
#   'called',
#   'the',
#   'oscars'],
#  ['does', 'the', 'percy', 'jackson', 'movie', 'suck'],
#  ['what',
#   'is',
#   'the',
#   'easy',
#   'way',
#   'to',
#   'use',
#   'a',
#   'delhi',
#   'bike',
#   'in',
#   'hyderabad'],
#  ['was',
#   'muhammed',
#   'a',
#   'narcissist',
#   'who',
#   'used',
#   'to',
#   'receive',
#   'convenient',
#   'revelations',
#   'for',
#   'his',
#   'benefit'],
#  ['what', 'is', 'the', 'force', 'of', 'a', 'wolf', 'bite'],
#  ['how',
#   'do',
#   'you',
#   'use',
#   'the',
#   'slack',
#   'tool',
#   'for',
#   'team',
#   'communication',
#   'what',
#   'pain',
#   'points',
#   'is',
#   'it',
#   'solving',
#   'for',
#   'you',
#   'how',
#   'do',
#   'you',
#   'share',
#   'files',
#   'with',
#   'slack',
#   'for',
#   'team',
#   'review'],
#  ['what',
#   'is',
#   'the',
#   'intermediate',
#   'value',
#   'theorem',
#   'how',
#   'do',
#   'you',
#   'find',
#   'it'],
#  ['what',
#   'is',
#   'meant',
#   'by',
#   'mainstream',
#   'culture',
#   'and',
#   'what',
#   'would',
#   'be',
#   'a',
#   'noteworthy',
#   'example',
#   'of',
#   'it'],
#  ['what', 'causes', 'the', 'underside', 'of', 'my', 'eye', 'to', 'twitch'],
#  ['does',
#   'santa',
#   'live',
#   'at',
#   'the',
#   'north',
#   'pole',
#   'or',
#   'was',
#   'there',
#   'really',
#   'a',
#   'mandela',
#   'effect',
#   'that',
#   'moved',
#   'him',
#   'to',
#   'finland'],
#  ['what', 'are', 'the', 'main', 'components', 'of', 'a', 'cologne'],
#  ['did', 'noam', 'chomsky', 'ever', 'meet', 'bertrand', 'russell'],
#  ['im',
#   'a',
#   '23',
#   'year',
#   'old',
#   'boy',
#   'with',
#   '58',
#   'kgs',
#   'weight',
#   'and',
#   'my',
#   'height',
#   'is',
#   '168',
#   'cms',
#   'do',
#   'i',
#   'still',
#   'have',
#   'a',
#   'chance',
#   'to',
#   'increase',
#   'my',
#   'height',
#   'if',
#   'yes',
#   'what',
#   'food',
#   'habits',
#   'should',
#   'i',
#   'follow'],
#  ['how',
#   'do',
#   'you',
#   'calculate',
#   'the',
#   'required',
#   'length',
#   'of',
#   'a',
#   'water',
#   'filled',
#   'pipe',
#   'that',
#   'is',
#   'gravity',
#   'fed',
#   'into',
#   'a',
#   'container',
#   'id',
#   'want',
#   'to',
#   'avoid',
#   'overfilling',
#   'the',
#   'container'],
#  ['how', 'do', 'i', 'keep', 'myself', 'motivated', 'during', 'hard', 'times'],
#  ['is', 'drinking', 'redbull', 'bad', 'for', 'health'],
#  ['which', 'are', 'best', 'wifi', 'devices'],
#  ['which', 'is', 'best', 'phone', 'under', '12k'],
#  ['as',
#   'an',
#   'engineering',
#   'student',
#   'who',
#   'loves',
#   'science',
#   'but',
#   'is',
#   'coming',
#   'to',
#   'hate',
#   'engineering',
#   'what',
#   'possible',
#   'cure',
#   'do',
#   'i',
#   'have'],
#  ['how',
#   'is',
#   'your',
#   'jet',
#   'black',
#   'iphone',
#   '7',
#   'holding',
#   'up',
#   'against',
#   'scratches'],
#  ['how',
#   'do',
#   'i',
#   'convert',
#   'a',
#   'kolkata',
#   'registration',
#   'privately',
#   'owned',
#   'car',
#   'to',
#   'commercial',
#   'one'],
#  ['what',
#   'are',
#   'some',
#   'tips',
#   'for',
#   'investing',
#   'in',
#   'an',
#   'airbnb',
#   'property'],
#  ['what', 'is', 'the', 'most', 'expensive', 'phone', 'in', 'the', 'world'],
#  ['i',
#   'sent',
#   'a',
#   'message',
#   'in',
#   'whatsapp',
#   'it',
#   'says',
#   'sent',
#   'not',
#   'delivered',
#   'was',
#   'it',
#   'seen'],
#  ['what', 'are', 'some', 'good', 'early', 'morning', 'habits'],
#  ['which', 'custom', 'rom', 'is', 'best'],
#  ['does',
#   'whatsapp',
#   'web',
#   'work',
#   'even',
#   'if',
#   'the',
#   'computer',
#   'and',
#   'the',
#   'phone',
#   'are',
#   'kilometers',
#   'away',
#   'is',
#   'an',
#   'internet',
#   'connection',
#   'the',
#   'only',
#   'requirement'],
#  ['how', 'do', 'i', 'hit', 'big', 'shots', 'in', 'cricket'],
#  ['i',
#   'am',
#   'a',
#   'female',
#   'capricorn',
#   'sun',
#   'sign',
#   'cancer',
#   'moon',
#   'sign',
#   'and',
#   'libra',
#   'rising',
#   'star',
#   'can',
#   'you',
#   'guess',
#   'what',
#   'im',
#   'like'],
#  ['can', 'i', 'find', 'some', 'answers', 'to', 'etg', 'testing'],
#  ['what', 'are', 'some', 'examples', 'of', 'monopolies', 'in', 'india'],
#  ['what', 'are', 'the', 'pros', 'cons', 'of', 'having', 'children'],
#  ['what', 'does', 'stack', 'overflow', 'lack'],
#  ['how', 'can', 'i', 'find', 'a', 'pro', 'bono', 'lawyer'],
#  ['two', 'bank', 'accounts', 'in', 'same', 'bank'],
#  ['what', 'do', 'you', 'think', 'this', 'painting', 'means'],
#  ['what',
#   'are',
#   'the',
#   'best',
#   'workouts',
#   'for',
#   'building',
#   'back',
#   'muscles'],
#  ['if',
#   'america',
#   'were',
#   'attacked',
#   'by',
#   '10',
#   'million',
#   'foreign',
#   'troops',
#   'could',
#   'they',
#   'handle',
#   'it',
#   'if',
#   'not',
#   'how',
#   'long',
#   'would',
#   'they',
#   'have',
#   'to',
#   'wait',
#   'for',
#   'help',
#   'to',
#   'arrive'],
#  ['are',
#   'there',
#   'any',
#   'alternative',
#   'question',
#   'and',
#   'answer',
#   'websites',
#   'to',
#   'quora'],
#  ['how', 'do', 'we', 'observe', 'planets', 'with', 'radio', 'telescopes'],
#  ['is',
#   'there',
#   'any',
#   'theory',
#   'that',
#   'explains',
#   'that',
#   'demonic',
#   'possessions',
#   'are',
#   'some',
#   'invention',
#   'for',
#   'making',
#   'people',
#   'get',
#   'interested',
#   'in',
#   'religion'],
#  ['do', 'i', 'have', 'to', 'wear', 'a', 'sports', 'bra', 'to', 'gym'],
#  ['what',
#   'are',
#   'personality',
#   'types',
#   'and',
#   'disorders',
#   'that',
#   'make',
#   'a',
#   'person',
#   'unable',
#   'to',
#   'feel',
#   'intimacy',
#   'and',
#   'impulse',
#   'to',
#   'limit',
#   'socializing',
#   'and',
#   'personal',
#   'relationships'],
#  ['if',
#   'earth',
#   'had',
#   'no',
#   'atmosphere',
#   'would',
#   'the',
#   'sky',
#   'appear',
#   'black'],
#  ['what',
#   'is',
#   'the',
#   'best',
#   'coaching',
#   'for',
#   'medical',
#   'entrance',
#   'in',
#   'nagpur'],
#  ['which',
#   'books',
#   'do',
#   'you',
#   'recommend',
#   'for',
#   'the',
#   'ca',
#   'ipcc',
#   'for',
#   'both',
#   'groups'],
#  ['how', 'can', 'i', 'pursue', 'journalism', 'after', 'my', 'btech', 'degree'],
#  ['how', 'come', 'all', 'countries', 'are', 'in', 'debt'],
#  ['what', '’', 's', 'your', 'creative', 'process'],
#  ['how',
#   'did',
#   'you',
#   'honestly',
#   'feel',
#   'finding',
#   'out',
#   'you',
#   'had',
#   'been',
#   'cheated',
#   'on',
#   'and',
#   'has',
#   'it',
#   'changed',
#   'you'],
#  ['which', 'are', 'the', 'rarest', 'world', 'war', 'pictures'],
#  ['how', 'do', 'you', 'cook', 'a', 'chicken', 'breast', 'in', 'a', 'oven'],
#  ['why',
#   'do',
#   'indians',
#   'spend',
#   'a',
#   'lot',
#   'of',
#   'money',
#   'on',
#   'marriage',
#   'rather',
#   'than',
#   'americans',
#   'or',
#   'europeans'],
#  ['should', 'we', 'all', 'buy', 'apple', 'stock', 'now'],
#  ['is',
#   'there',
#   'really',
#   'a',
#   'chip',
#   'embedded',
#   'in',
#   'the',
#   'new',
#   'rupees',
#   '2000',
#   'note'],
#  ['is',
#   'there',
#   'a',
#   'difference',
#   'in',
#   'feeling',
#   'versus',
#   'measuring',
#   'progress',
#   'in',
#   'actually',
#   'making',
#   'progress'],
#  ['how', 'do', 'i', 'contact', 'airbnb', 'customer', 'support'],
#  ['is', 'mcom', 'worth', 'doing', 'from', 'srcc'],
#  ['what',
#   'are',
#   'the',
#   'dangers',
#   'of',
#   'taking',
#   'valium',
#   'and',
#   'percocet',
#   'at',
#   'the',
#   'same',
#   'time'],
#  ['what', 'is', 'the', 'best', 'glue', 'for', 'shoe', 'repair'],
#  ['my',
#   'percentage',
#   'is',
#   '62',
#   'in',
#   'btechi',
#   'want',
#   'to',
#   'join',
#   'into',
#   'niit',
#   'institutedo',
#   'they',
#   'provide',
#   'me',
#   'a',
#   'job',
#   'in',
#   'good',
#   'mncs',
#   'with',
#   'that',
#   'percentagehow',
#   'worthytojoin',
#   'niit'],
#  ['how',
#   'can',
#   'an',
#   'unhealthy',
#   'woman',
#   'like',
#   'hillary',
#   'become',
#   'the',
#   'president',
#   'of',
#   'the',
#   'usa',
#   'dont',
#   'her',
#   'supporters',
#   'know',
#   'that',
#   'she',
#   'is',
#   'terribly',
#   'ill'],
#  ['amazon',
#   'interview',
#   'what',
#   'is',
#   'the',
#   'best',
#   'answer',
#   'to',
#   'the',
#   'question',
#   'why',
#   'amazon'],
#  ['what', 'does', 'ad', 'stand', 'for'],
#  ['how',
#   'do',
#   'you',
#   'cut',
#   'line',
#   'externally',
#   'and',
#   'internally',
#   'in',
#   'maths'],
#  ['can',
#   'we',
#   'prepare',
#   'for',
#   'the',
#   'jee',
#   'main',
#   'in',
#   'the',
#   'last',
#   '4',
#   'months',
#   'and',
#   'get',
#   '180',
#   'or',
#   'more',
#   'i',
#   'have',
#   'studied',
#   'well',
#   'but',
#   'low',
#   'on',
#   'confidence'],
#  ['what',
#   'will',
#   'happen',
#   'to',
#   'a',
#   'person',
#   'who',
#   'has',
#   'bot',
#   'opposite',
#   'phobia',
#   'apeirophobia',
#   'and',
#   'thanatophobia'],
#  ['will',
#   'slow',
#   'and',
#   'smooth',
#   'driving',
#   'of',
#   'two',
#   'wheeler',
#   'in',
#   'indian',
#   'road',
#   'conditions',
#   'prevent',
#   'backspine',
#   'related',
#   'problems'],
#  ['how', 'should', 'i', 'live', 'my', 'life'],
#  ['how', 'do', 'i', 'overcome', 'pimples', 'due', 'to', 'pcod'],
#  ['what', 'will', 'be', 'the', 'journal', 'entries', 'for', 'discount'],
#  ['what',
#   'is',
#   'the',
#   'maximum',
#   'number',
#   'of',
#   'times',
#   'you',
#   'can',
#   'fold',
#   'a',
#   'piece',
#   'of',
#   'paper'],
#  ['as',
#   'shia',
#   'is',
#   'a',
#   'denomination',
#   'of',
#   'islam',
#   'why',
#   'is',
#   'the',
#   'shia',
#   'majority',
#   'iraq',
#   'being',
#   'opposed',
#   'by',
#   'isis',
#   'islamic',
#   'state',
#   'of',
#   'iraq',
#   'and',
#   'syria'],
#  ['how', 'can', 'approach', 'guy', 'i', 'like'],
#  ['can',
#   'hillary',
#   'clinton',
#   'pardon',
#   'herself',
#   'if',
#   'she',
#   'is',
#   'elected',
#   'as',
#   'president'],
#  ['is',
#   'it',
#   'too',
#   'late',
#   'for',
#   'any',
#   'age',
#   'person',
#   'to',
#   'learn',
#   'computer',
#   'programing'],
#  ['i',
#   'am',
#   'doing',
#   'bachelors',
#   'in',
#   'computer',
#   'science',
#   'i',
#   'will',
#   'be',
#   'done',
#   'with',
#   'my',
#   '4th',
#   'semester',
#   'in',
#   'few',
#   'days',
#   'i',
#   'have',
#   '3',
#   'month',
#   'of',
#   'summer',
#   'vacation',
#   'ahead',
#   'what',
#   'is',
#   'the',
#   'best',
#   'way',
#   'i',
#   'can',
#   'utilize',
#   'these',
#   '3',
#   'months',
#   'so',
#   'i',
#   'can',
#   'land',
#   'a',
#   'good',
#   'internshipjob',
#   'in',
#   'future',
#   'at',
#   'a',
#   'top',
#   'notch',
#   'company',
#   'like',
#   'microsoft',
#   'google',
#   'facebook',
#   'etc'],
#  ['what',
#   'is',
#   'the',
#   'best',
#   'point',
#   'and',
#   'shoot',
#   'camera',
#   'under',
#   '7k'],
#  ['how', 'do', 'i', 'research', 'for', 'mun'],
#  ['how',
#   'do',
#   'you',
#   'know',
#   'if',
#   'your',
#   'boyfriend',
#   'actually',
#   'loves',
#   'you'],
#  ['what',
#   'are',
#   'the',
#   'books',
#   'required',
#   'for',
#   'btech',
#   'it',
#   'first',
#   'year'],
#  ['what', 'are', 'some', 'spanish', 'inventions', 'we', 'use', 'daily'],
#  ['how',
#   'will',
#   'you',
#   'ensure',
#   'that',
#   'that',
#   'the',
#   'next',
#   'military',
#   'intervention',
#   'by',
#   'us',
#   'is',
#   'a',
#   'genuine',
#   'one'],
#  ['which', 'human', 'race', 'is', 'most', 'evolved'],
#  ['what',
#   'is',
#   'a',
#   'good',
#   'coaching',
#   'institute',
#   'for',
#   'cfa',
#   'in',
#   'chennai'],
#  ['is',
#   'there',
#   'a',
#   'free',
#   'version',
#   'of',
#   'vmware',
#   'vsphere',
#   'hypervisor',
#   'if',
#   'not',
#   'which',
#   'are',
#   'some',
#   'effective',
#   'alternatives'],
#  ['what', 'does', 'the', '12th', 'amendment', 'mean'],
#  ['how',
#   'would',
#   'you',
#   'describe',
#   'india',
#   'in',
#   'one',
#   'sentence',
#   'to',
#   'someone',
#   'from',
#   'north',
#   'america',
#   'who',
#   'has',
#   'never',
#   'been',
#   'to',
#   'india'],
#  ['which',
#   'book',
#   'is',
#   'better',
#   'for',
#   'understand',
#   'basics',
#   'sterength',
#   'of',
#   'material'],
#  ['what',
#   'does',
#   'shakespeare',
#   'mean',
#   'by',
#   'a',
#   'little',
#   'more',
#   'than',
#   'kin',
#   'and',
#   'less',
#   'than',
#   'kind'],
#  ['can', 'eating', 'boiled', 'egg', 'or', 'omelette', 'cause', 'bird', 'flu'],
#  ['should',
#   'i',
#   'try',
#   'to',
#   'find',
#   'out',
#   'who',
#   'my',
#   'birth',
#   'father',
#   'is'],
#  ['how',
#   'much',
#   'initial',
#   'capital',
#   'would',
#   'you',
#   'need',
#   'to',
#   'become',
#   'an',
#   'investor',
#   'successfully',
#   'like',
#   'warren',
#   'buffet',
#   'if',
#   'you',
#   'are',
#   '21'],
#  ['why', 'is', 'the', 'singapore', 'education', 'system', 'so', 'good'],
#  ['is', 'your', 'education', 'worth', 'it'],
#  ['would',
#   'it',
#   'be',
#   'feasible',
#   'to',
#   'genetically',
#   'engineer',
#   'humans',
#   'to',
#   'have',
#   'two',
#   'hearts'],
#  ['has',
#   'any',
#   'us',
#   'presidential',
#   'candidate',
#   'sold',
#   'cabinet',
#   'positions',
#   'in',
#   'his',
#   'administration',
#   'in',
#   'return',
#   'for',
#   'campaign',
#   'contributions'],
#  ['which',
#   'is',
#   'the',
#   'best',
#   'north',
#   'indian',
#   'food',
#   'restaurant',
#   'in',
#   'karkardooma'],
#  ['how', 'do', 'you', 'make', 'a', 'bass', 'fish', 'trap'],
#  ['does', 'lime', 'juice', 'go', 'bad'],
#  ['what', 'are', 'disadvantages', 'of', 'a', 'love', 'marriage'],
#  ['can', 'i', 'change', 'my', 'branch', 'in', 'davv', 'indore'],
#  ['how', 'much', 'are', 'diamonds', 'worth'],
#  ['what', 'is', 'a', 'fair', 'startup', 'salary'],
#  ['which', 'are', 'best', 'private', 'medical', 'colleges'],
#  ['what',
#   'are',
#   'the',
#   'lyrics',
#   'for',
#   'what',
#   'is',
#   'love',
#   'by',
#   'haddaway'],
#  ['if',
#   'you',
#   'throw',
#   'up',
#   'within',
#   '30',
#   'minutes',
#   'of',
#   'eating',
#   'how',
#   'many',
#   'calories',
#   'do',
#   'you',
#   'lose',
#   'of',
#   'the',
#   'food',
#   'you',
#   'ate'],
#  ['how', 'do', 'i', 'participate', 'in', 'splitsvilla'],
#  ['which',
#   'it',
#   'companies',
#   'in',
#   'kolkata',
#   'offer',
#   'internships',
#   'to',
#   'bca',
#   'students'],
#  ['how', 'do', 'i', 'bolster', 'my', 'selfesteem'],
#  ['how', 'do', 'i', 'teach', 'a', 'child', 'to', 'read', 'and', 'write'],
#  ['how', 'do', 'we', 'prove', 'math1frac1nn', '1', 'frac1n1n1math'],
#  ['what',
#   'is',
#   'the',
#   'difference',
#   'between',
#   'inheritance',
#   'encapsulation',
#   'and',
#   'polymorphism'],
#  ['why', 'have', 'i', 'not', 'seen', 'my', 'period'],
#  ['how', 'can', 'i', 'read', 'this', 'time'],
#  ['what',
#   'is',
#   'the',
#   'prescribed',
#   'book',
#   'for',
#   'mechanical',
#   'engineer',
#   'students',
#   'to',
#   'clear',
#   'the',
#   'isro',
#   'scientistengineer',
#   'sc',
#   'exam'],
#  ['i',
#   'have',
#   'still',
#   'not',
#   'prepared',
#   'constructions',
#   'locus',
#   'and',
#   'graphs',
#   'in',
#   'mathswould',
#   'i',
#   'will',
#   'be',
#   'able',
#   'to',
#   'score',
#   '100',
#   'in',
#   'icse',
#   'maths'],
#  ['what',
#   'ethical',
#   'issues',
#   'do',
#   'operators',
#   'of',
#   'restaurant',
#   'need',
#   'to',
#   'be',
#   'aware',
#   'of'],
#  ['how',
#   'much',
#   'money',
#   'are',
#   'artists',
#   'currently',
#   'making',
#   'off',
#   'of',
#   'spotify'],
#  ['which',
#   'episode',
#   'of',
#   'star',
#   'trek',
#   'tos',
#   'features',
#   'slimy',
#   'things',
#   'which',
#   'gets',
#   'itself',
#   'glued',
#   'to',
#   'the',
#   'crew'],
#  ['which',
#   'is',
#   'a',
#   'suitable',
#   'inpatient',
#   'drug',
#   'and',
#   'alcohol',
#   'rehab',
#   'center',
#   'near',
#   'putnam',
#   'county',
#   'in'],
#  ['are', 'a', 'grades', 'enough', 'to', 'get', 'into', 'cambridge'],
#  ['how',
#   'good',
#   'is',
#   'the',
#   '17',
#   'hmr',
#   'rifle',
#   'for',
#   'coyote',
#   'hunting'],
#  ['i',
#   'got',
#   'letter',
#   'of',
#   'intent',
#   'to',
#   'hire',
#   'from',
#   'infosys',
#   'will',
#   'i',
#   'be',
#   'surely',
#   'called',
#   'by',
#   'infosys'],
#  ['how', 'does', 'raspberry', 'pi', 'work'],
#  ['how', 'long', 'does', 'it', 'take', 'to', 'open', 'an', 'llc'],
#  ['what',
#   'is',
#   'your',
#   'opinion',
#   'of',
#   'the',
#   'quote',
#   'most',
#   'peoples',
#   'lives',
#   'are',
#   'a',
#   'direct',
#   'reflection',
#   'of',
#   'the',
#   'expectations',
#   'of',
#   'their',
#   'peer',
#   'group'],
#  ['scope',
#   'for',
#   'csebtechbe',
#   'graduates',
#   'to',
#   'get',
#   'foreign',
#   'job',
#   'if',
#   'yes',
#   'then',
#   'how'],
#  ['where',
#   'should',
#   'i',
#   'go',
#   'to',
#   'get',
#   'cheap',
#   'goats',
#   'milk',
#   'in',
#   'the',
#   'uk'],
#  ['i',
#   'am',
#   'an',
#   'arts',
#   'graduate',
#   'can',
#   'do',
#   'rhce',
#   'certification',
#   'and',
#   'get',
#   'a',
#   'job',
#   'in',
#   'india'],
#  ['what',
#   'is',
#   'the',
#   'most',
#   'creative',
#   'way',
#   'you',
#   'can',
#   'break',
#   'a',
#   'clock'],
#  ['how',
#   'do',
#   'i',
#   'solve',
#   'the',
#   'following',
#   'problem',
#   'is',
#   'it',
#   'possible',
#   'to',
#   'solve',
#   'using',
#   'segment',
#   'trees',
#   'are',
#   'there',
#   'any',
#   'efficient',
#   'methods'],
#  ['what',
#   'can',
#   'i',
#   'use',
#   'to',
#   'host',
#   'a',
#   '1',
#   'table',
#   'database',
#   'that',
#   'will',
#   'be',
#   'used',
#   'by',
#   'a',
#   'mobile',
#   'app'],
#  ['i',
#   'would',
#   'like',
#   'to',
#   'declutter',
#   'my',
#   'life',
#   'and',
#   'become',
#   'a',
#   'minimalist',
#   'i',
#   'am',
#   'finding',
#   'it',
#   'i',
#   'very',
#   'difficult',
#   'to',
#   'get',
#   'rid',
#   'of',
#   'stuff',
#   'is',
#   'there',
#   'a',
#   'way',
#   'to',
#   'outsource',
#   'this'],
#  ['how', 'are', 'long', 'distance', 'relationships', 'maintained'],
#  ['how',
#   'many',
#   'worlds',
#   'are',
#   'there',
#   'in',
#   'super',
#   'mario',
#   'bros',
#   'wii'],
#  ['what', 'are', 'examples', 'of', 'brilliant', 'medical', 'strategy'],
#  ['do', 'physical', 'laws', 'change', 'over', 'time'],
#  ['did',
#   'mark',
#   'zuckerberg',
#   'steal',
#   'the',
#   'idea',
#   'of',
#   'facebook',
#   'from',
#   'cameron',
#   'winklevoss'],
#  ['what',
#   'kind',
#   'of',
#   'advanced',
#   'c',
#   'features',
#   'i',
#   'need',
#   'to',
#   'learn',
#   'if',
#   'i',
#   'want',
#   'to',
#   'work',
#   'for',
#   'google'],
#  ['how', 'can', 'i', 'activate', 'two', 'jio', 'sims', 'in', 'one', 'phone'],
#  ['what', 'are', 'the', 'ranks', 'in', 'the', 'navy', 'seals'],
#  ['which',
#   'software',
#   'is',
#   'best',
#   'for',
#   'stock',
#   'and',
#   'options',
#   'automated',
#   'trading',
#   'in',
#   'india'],
#  ['what', 'animals', 'begin', 'with', 'the', 'letter', 'x'],
#  ['why',
#   'dont',
#   'more',
#   'americans',
#   'aspire',
#   'to',
#   'public',
#   'sector',
#   'civil',
#   'service',
#   'jobs'],
#  ['did',
#   'god',
#   'punish',
#   'slave',
#   'masters',
#   'who',
#   'didnt',
#   'treat',
#   'their',
#   'slaves',
#   'fairly'],
#  ['which',
#   'two',
#   'bollywood',
#   'actors',
#   'or',
#   'actresses',
#   'most',
#   'resemble',
#   'each',
#   'other'],
#  ['what', 'is', 'the', 'best', 'software', 'company', 'in', 'chennai'],
#  ['in',
#   'american',
#   'history',
#   'has',
#   'any',
#   'republican',
#   'ever',
#   'owned',
#   'a',
#   'slave'],
#  ['how',
#   'one',
#   'should',
#   'begin',
#   'to',
#   'prepare',
#   'for',
#   'iiit',
#   'h',
#   'lateral',
#   'entry',
#   'from',
#   'first',
#   'year'],
#  ['how',
#   'does',
#   'demographic',
#   'momentum',
#   'function',
#   'in',
#   'human',
#   'geography'],
#  ['im',
#   'a',
#   'self',
#   'trained',
#   'amateur',
#   'artist',
#   'from',
#   'engineering',
#   'background',
#   'currently',
#   'im',
#   'working',
#   'for',
#   'cts',
#   'and',
#   'the',
#   'job',
#   'is',
#   'very',
#   'frustrating',
#   'for',
#   'me',
#   'how',
#   'can',
#   'i',
#   'breakfree',
#   'from',
#   'my',
#   'dull',
#   'job',
#   'and',
#   'pursue',
#   'a',
#   'career',
#   'in',
#   'art'],
#  ['which', 'is', 'the', 'craziest', 'moment', 'of', 'your', 'college', 'life'],
#  ['should', 'i', 'get', 'an', 'mba', 'in', 'agribusiness'],
#  ['why',
#   'do',
#   'i',
#   'sometimes',
#   'feel',
#   'like',
#   'the',
#   'people',
#   'i',
#   'know',
#   'are',
#   'watching',
#   'me'],
#  ['how', 'do', 'i', 'use', 'bitcoin', 'in', 'singapore'],
#  ['what',
#   'news',
#   'sources',
#   'do',
#   'diplomats',
#   'read',
#   'to',
#   'get',
#   'global',
#   'macro',
#   'perspectives'],
#  ['why',
#   'am',
#   'i',
#   'feeling',
#   'uncomfortable',
#   'to',
#   'make',
#   'eye',
#   'contact'],
#  ['how', 'is', 'dtu'],
#  ['as',
#   'a',
#   'foreigner',
#   'what',
#   'things',
#   'do',
#   'you',
#   'dislike',
#   'about',
#   'america',
#   'or',
#   'american',
#   'people'],
#  ['i',
#   'am',
#   'in',
#   'eighth',
#   'grade',
#   'and',
#   'i',
#   'got',
#   'a',
#   '1700',
#   'on',
#   'my',
#   'lexile',
#   'test',
#   'is',
#   'this',
#   'good',
#   'or',
#   'bad',
#   'and',
#   'what',
#   'does',
#   'it',
#   'mean'],
#  ['what',
#   'are',
#   'some',
#   'of',
#   'the',
#   'best',
#   'emerging',
#   'storytelling',
#   'formats'],
#  ['how', 'do', 'i', 'become', 'a', 'good', 'teachertutor'],
#  ['what', 'is', 'the', 'best', 'belgian', 'beer'],
#  ['what',
#   'were',
#   'the',
#   'origins',
#   'of',
#   'the',
#   'first',
#   'languages',
#   'and',
#   'what',
#   'were',
#   'these',
#   'languages'],
#  ['if',
#   'north',
#   'korea',
#   'were',
#   'to',
#   'attack',
#   'south',
#   'korea',
#   'suddenly',
#   'how',
#   'would',
#   'the',
#   'latter',
#   'with',
#   'its',
#   'ally',
#   'usa',
#   'defend',
#   'itself'],
#  ['what',
#   'does',
#   'it',
#   'mean',
#   'if',
#   'a',
#   'website',
#   'is',
#   'hosted',
#   'on',
#   'a',
#   'load',
#   'balanced',
#   'web',
#   'server',
#   'and',
#   'that',
#   'sticky',
#   'sessions',
#   'would',
#   'have',
#   'to',
#   'be',
#   'enabled',
#   'on',
#   'the',
#   'load',
#   'balancers',
#   'and',
#   'that',
#   'session',
#   'checks',
#   'would',
#   'have',
#   'to',
#   'be',
#   'done',
#   'on',
#   'page',
#   'loads'],
#  ['why', 'do', 'i', 'smile', 'even', 'when', 'i', 'dont', 'want', 'to'],
#  ['what',
#   'do',
#   'mobile',
#   'and',
#   'home',
#   'mean',
#   'on',
#   'the',
#   'whatsapp',
#   'contacts',
#   'page'],
#  ['i',
#   'feel',
#   'like',
#   'disappearing',
#   'from',
#   'this',
#   'world',
#   'no',
#   'moneyfamecareer',
#   'seems',
#   'lucrative',
#   'enough',
#   'to',
#   'stay',
#   'back',
#   'does',
#   'anyone',
#   'feel',
#   'the',
#   'same'],
#  ['does', 'girls', 'like', 'big', 'penis'],
#  ['is', 'it', 'illegal', 'to', 'send', 'cash', 'through', 'the', 'mail'],
#  ['why',
#   'do',
#   'mother',
#   'cats',
#   'sometimes',
#   'eat',
#   'their',
#   'own',
#   'kittens'],
#  ['i',
#   'am',
#   'planning',
#   'to',
#   'learn',
#   'a',
#   'framework',
#   'oaf',
#   'or',
#   'adf',
#   'any',
#   'suggestions',
#   'which',
#   'is',
#   'better',
#   'for',
#   'present',
#   'situation'],
#  ['what',
#   'are',
#   'the',
#   'best',
#   'love',
#   'story',
#   'movies',
#   'just',
#   'as',
#   'titanic'],
#  ['what', 'are', 'the', 'pros', 'and', 'cons', 'of', 'shopify'],
#  ['whats', 'the', 'inverse', 'function'],
#  ['how', 'do', 'i', 'copyright', 'a', 'logo'],
#  ['what', 'was', 'it', 'like', 'to', 'travel', 'on', 'board', 'a', 'concorde'],
#  ['how', 'can', 'i', 'live', 'a', 'simple', 'life'],
#  ['what',
#   'does',
#   'it',
#   'mean',
#   'when',
#   'a',
#   'girl',
#   'grabs',
#   'your',
#   'erect',
#   'penis'],
#  ['which',
#   'countries',
#   'have',
#   'the',
#   'tradition',
#   'of',
#   'taking',
#   'off',
#   'shoes',
#   'before',
#   'you',
#   'enter',
#   'a',
#   'home'],
#  ['why', 'is', 'a', 'university', 'degree', 'so', 'important'],
#  ['what', 'is', 'mentoring'],
#  ['how',
#   'do',
#   'you',
#   'cope',
#   'with',
#   'being',
#   'scammed',
#   'and',
#   'losing',
#   'a',
#   'lot',
#   'of',
#   'money',
#   'knowing',
#   'you',
#   'will',
#   'not',
#   'get',
#   'it',
#   'back'],
#  ['how', 'much', 'does', 'starting', 'a', 'website', 'cost'],
#  ['can', 'a', 'foreigner', 'buy', 'american', 'mutual', 'funds'],
#  ['why',
#   'is',
#   'my',
#   'google',
#   'in',
#   'a',
#   'foreign',
#   'language',
#   'on',
#   'safari'],
#  ['what',
#   'is',
#   'the',
#   'best',
#   'app',
#   'to',
#   'block',
#   'unwanted',
#   'voice',
#   'messages',
#   'and',
#   'calls'],
#  ['is', 'taiwan', 'part', 'of', 'or', 'separate', 'from', 'china'],
#  ['is', 'playing', 'chess', 'waste', 'of', 'time'],
#  ['is', 'nude', 'photography', 'considered', 'objectification'],
#  ['what',
#   'is',
#   'buried',
#   'or',
#   'was',
#   'buried',
#   'under',
#   'solomons',
#   'temple'],
#  ['between',
#   'mac',
#   'os',
#   'and',
#   'windows',
#   'which',
#   'os',
#   'should',
#   'i',
#   'chose',
#   'as',
#   'a',
#   'web',
#   'developer'],
#  ['do', 'shock', 'collars', 'work', 'on', 'dogs'],
#  ['why', 'is', 'the', 'yale', 'art', 'website', 'so', 'bad'],
#  ['how',
#   'has',
#   'your',
#   'lifestyle',
#   'changed',
#   'before',
#   'and',
#   'after',
#   'using',
#   'quora'],
#  ['how', 'do', 'i', 'choose', 'a', 'topic', 'for', 'my', 'blog'],
#  ['what',
#   'exactly',
#   'does',
#   'borderline',
#   'personality',
#   'disorder',
#   'mean',
#   'and',
#   'what',
#   'are',
#   'the',
#   'symptoms'],
#  ['why', 'do', 'i', 'enjoy', 'hurting', 'myself'],
#  ['how', 'do', 'you', 'clean', 'out', 'a', 'catalytic', 'converter'],
#  ['what', 'are', 'best', 'things', 'to', 'be', 'learned', 'in', 'life'],
#  ['do',
#   'girls',
#   'stop',
#   'growing',
#   'in',
#   'height',
#   'once',
#   'they',
#   'get',
#   'their',
#   'periods'],
#  ['where',
#   'could',
#   'i',
#   'find',
#   'a',
#   'best',
#   'escort',
#   'agency',
#   'in',
#   'malaysia'],
#  ['which',
#   'is',
#   'the',
#   'best',
#   'ias',
#   'coaching',
#   'centre',
#   'in',
#   'trivandrum'],
#  ['what',
#   'does',
#   'it',
#   'mean',
#   'when',
#   'a',
#   'girl',
#   'says',
#   'youre',
#   'so',
#   'affectionate'],
#  ['why', 'is', 'virginity', 'a', 'big', 'deal', 'in', 'society'],
#  ['what',
#   'is',
#   'the',
#   'character',
#   'or',
#   'theory',
#   'that',
#   'you',
#   'believe',
#   'to',
#   'be',
#   'true',
#   'while',
#   'most',
#   'people',
#   'dont',
#   'why'],
#  ['why', 'do', 'i', 'get', 'bored', 'easily'],
#  ['what', 'should', 'i', 'learn', 'php', 'or', 'net'],
#  ['what', 'is', 'the', 'virgin'],
#  ['are', 'turks', 'and', 'azerbaijanis', 'considered', 'white'],
#  ['what', 'should', 'i', 'do', 'with', 'my', 'career', 'life'],
#  ['what',
#   'do',
#   'you',
#   'think',
#   'of',
#   'the',
#   'reliance',
#   'jio',
#   'ad',
#   'featuring',
#   'prime',
#   'minister',
#   'modi',
#   'do',
#   'you',
#   'think',
#   'its',
#   'legally',
#   'or',
#   'ethically',
#   'correct',
#   'to',
#   'do',
#   'so'],
#  ['how',
#   'does',
#   'one',
#   'train',
#   'to',
#   'become',
#   'a',
#   'world',
#   'champion',
#   'pole',
#   'dancer'],
#  ['how',
#   'do',
#   'people',
#   'feel',
#   'when',
#   'the',
#   'borders',
#   'of',
#   'their',
#   'country',
#   'change'],
#  ['how',
#   'does',
#   'mypromovideo',
#   'of',
#   'youtube',
#   'make',
#   'there',
#   'animation'],
#  ['do', 'lizards', 'feel', 'thirsty'],
#  ['scs',
#   'what',
#   'would',
#   'happen',
#   'to',
#   'the',
#   'appointment',
#   'of',
#   'arbitrators',
#   'made',
#   'by',
#   'the',
#   'president',
#   'itlos',
#   'if',
#   'china',
#   'did',
#   'not',
#   'approve',
#   'it'],
#  ['my',
#   'husband',
#   'was',
#   'so',
#   'mean',
#   'for',
#   'most',
#   'our',
#   '20',
#   'yr',
#   'relationship',
#   'but',
#   'the',
#   'past',
#   'couple',
#   'of',
#   'years',
#   'hes',
#   'started',
#   'being',
#   'nice',
#   'how',
#   'can',
#   'i',
#   'get',
#   'past',
#   'the',
#   'painful',
#   'memories'],
#  ['what', 'are', 'the', 'best', 'programming', 'practice', 'sites'],
#  ['what', 'are', 'compulsory', 'acts', 'of', 'worship', 'in', 'islam'],
#  ['what',
#   'would',
#   'be',
#   'your',
#   'advice',
#   'to',
#   'those',
#   'who',
#   'want',
#   'to',
#   'build',
#   'a',
#   'social',
#   'enterprise',
#   'but',
#   'have',
#   'no',
#   'prior',
#   'background',
#   'in',
#   'the',
#   'field',
#   'nor',
#   'an',
#   'advanced',
#   'education'],
#  ['how',
#   'do',
#   'you',
#   'achieve',
#   'the',
#   'freezing',
#   'point',
#   'of',
#   'hexane',
#   'how',
#   'does',
#   'it',
#   'compare',
#   'to',
#   'methane'],
#  ['would',
#   'you',
#   'trust',
#   'meth',
#   'users',
#   'andor',
#   'are',
#   '“',
#   'meth',
#   'users',
#   'mean',
#   'and',
#   'selfish',
#   '”'],
#  ['should',
#   'new',
#   'actors',
#   'start',
#   'in',
#   'commercials',
#   'to',
#   'build',
#   'up',
#   'their',
#   'acting',
#   'credits',
#   'then',
#   'focus',
#   'on',
#   'filmtv',
#   'after'],
#  ['what', 'is', 'lamictal', 'abuse'],
#  ['how',
#   'dangerous',
#   'is',
#   'it',
#   'if',
#   'a',
#   'dog',
#   'eats',
#   'chocolate',
#   'cake'],
#  ['would',
#   'vegans',
#   'view',
#   'animal',
#   'consumption',
#   'as',
#   'morally',
#   'permissible',
#   'if',
#   'the',
#   'animals',
#   'were',
#   'allowed',
#   'a',
#   'full',
#   'life',
#   'and',
#   'only',
#   'consumed',
#   'after',
#   'dying',
#   'from',
#   'natural',
#   'causes'],
#  ['what',
#   'is',
#   'most',
#   'appropriate',
#   'software',
#   'design',
#   'approach',
#   'topdown',
#   'or',
#   'bottomup',
#   'in',
#   'agile',
#   'world',
#   'does',
#   'anybody',
#   'really',
#   'design',
#   'anymore'],
#  ['what', 'did', 'the', 'catholic', 'reformation', 'change'],
#  ['how', 'is', 'correct', 'biblical', 'interpretation', 'determined'],
#  ['who',
#   'lived',
#   'in',
#   'indonesia',
#   'in',
#   'the',
#   'year',
#   '2000',
#   'bce',
#   'what',
#   'happened',
#   'to',
#   'them'],
#  ['can', 'you', 'see', 'through', 'a', 'tinted', 'window', 'of', 'a', 'car'],
#  ['sex', 'how', 'do', 'i', 'put', 'my', 'penis', 'in', 'a', 'vagina'],
#  ['what', 'are', 'some', 'unisex', 'japanese', 'names'],
#  ['how',
#   'do',
#   'i',
#   'calculate',
#   'the',
#   'gpa',
#   'for',
#   'universities',
#   'in',
#   'the',
#   'us'],
#  ['is',
#   'there',
#   'any',
#   'online',
#   'crash',
#   'course',
#   'for',
#   'cat',
#   '2016',
#   'available'],
#  ['what',
#   'is',
#   'it',
#   'like',
#   'to',
#   'work',
#   'at',
#   'thoughtworks',
#   'i',
#   '̇',
#   'stanbul'],
#  ['what', 'is', 'deep', 'data'],
#  ['my',
#   'friend',
#   'just',
#   'got',
#   'placed',
#   'in',
#   'fidelity',
#   'but',
#   'she',
#   'has',
#   'failed',
#   'in',
#   'a',
#   'subject',
#   'how',
#   'will',
#   'that',
#   'affect',
#   'her',
#   'job',
#   'security'],
#  ['what',
#   'are',
#   'the',
#   'most',
#   'important',
#   'habits',
#   'for',
#   'eating',
#   'healthy',
#   'and',
#   'losing',
#   'weight'],
#  ['what',
#   'is',
#   'the',
#   'homework',
#   'a',
#   'founder',
#   'must',
#   'do',
#   'before',
#   'starting',
#   'up'],
#  ['who', 'is', 'your', 'favorite', 'bollywood', 'actor', 'and', 'why'],
#  ['what',
#   'is',
#   'the',
#   'lowest',
#   'temperature',
#   'a',
#   'fire',
#   'can',
#   'survive',
#   'in'],
#  ['which',
#   'are',
#   'some',
#   'of',
#   'the',
#   'key',
#   'points',
#   'you',
#   'remember',
#   'on',
#   'the',
#   'books',
#   'you',
#   'have',
#   'read'],
#  ['how',
#   'do',
#   'you',
#   'turn',
#   'down',
#   'someones',
#   'idea',
#   'nicely',
#   'after',
#   'they',
#   'have',
#   'shown',
#   'so',
#   'much',
#   'passion',
#   'about',
#   'it'],
#  ['which', 'are', 'the', 'best', 'songs', 'of', 'lata', 'mangeshkar'],
#  ['i',
#   'want',
#   'to',
#   'be',
#   'a',
#   'top',
#   'class',
#   'programmer',
#   'in',
#   'my',
#   'life',
#   'how',
#   'many',
#   'problems',
#   'should',
#   'i',
#   'solve',
#   'each',
#   'day',
#   'to',
#   'achieve',
#   'my',
#   'goal'],
#  ['whats', 'creative', 'writing'],
#  ['why', 'do', 'i', 'keep', 'getting', 'small', 'cuts', 'on', 'my', 'hands'],
#  ['is', 'helium', 'considered', 'an', 'inert', 'gas', 'if', 'not', 'why'],
#  ['what', 'if', 'i', 'dont', 'pass', 'the', 'ccna', 'exam'],
#  ['what', 'is', 'the', 'weirdest', 'question', 'ever', 'asked', 'on', 'quora'],
#  ['if', 'china', 'is', 'developed', 'country'],
#  ['can', 'i', 'read', 'deleted', 'messages', 'kik'],
#  ['how', 'can', 'i', 'get', 'more', 'followers', 'in', 'fb'],
#  ['how',
#   'it',
#   'is',
#   'to',
#   'use',
#   'a',
#   'react',
#   'component',
#   'in',
#   'a',
#   'angularjs',
#   'application'],
#  ['why',
#   'am',
#   'i',
#   'not',
#   'able',
#   'to',
#   'get',
#   'over',
#   'my',
#   'past',
#   'relationship'],
#  ['what',
#   'are',
#   'the',
#   'best',
#   'countries',
#   'to',
#   'volunteer',
#   'in',
#   'peace',
#   'corps'],
#  ['what', 'can', 'i', 'do', 'to', 'detox', 'from', 'marijuana'],
#  ['dating',
#   'and',
#   'relationships',
#   'what',
#   'are',
#   'the',
#   'keys',
#   'to',
#   'a',
#   'successful',
#   'relationship'],
#  ['what',
#   'happens',
#   'when',
#   'you',
#   'stop',
#   'consuming',
#   'synthroid',
#   'abruptly'],
#  ['what',
#   'is',
#   'it',
#   'like',
#   'to',
#   'know',
#   'someone',
#   'with',
#   'dissociative',
#   'identity',
#   'disorder',
#   'or',
#   'be',
#   'someone',
#   'with',
#   'the',
#   'disorder'],
#  ['in',
#   'which',
#   'province',
#   'of',
#   'china',
#   'did',
#   'bao',
#   'xiruo',
#   'save',
#   'wanyan',
#   'honglie'],
#  ['what',
#   'do',
#   'pigs',
#   'eat',
#   'on',
#   'the',
#   'farm',
#   'how',
#   'is',
#   'their',
#   'food',
#   'prepare'],
#  ['why',
#   'has',
#   'weight',
#   'loss',
#   'reached',
#   'stagnancy',
#   'in',
#   'spite',
#   'of',
#   'me',
#   'doing',
#   'exercise',
#   'daily',
#   'and',
#   'following',
#   'a',
#   'diet',
#   'plan',
#   'which',
#   'has',
#   'helped',
#   'me',
#   'lose',
#   '16',
#   'kilogram',
#   'of',
#   'weight'],
#  ['why', 'should', 'someone', 'accept', 'anything', 'one', 'is', 'given'],
#  ['how',
#   'long',
#   'will',
#   'it',
#   'take',
#   'the',
#   'earths',
#   'core',
#   'to',
#   'cool',
#   'enough',
#   'to',
#   'halt',
#   'tectonic',
#   'activity'],
#  ['what',
#   'is',
#   'the',
#   'value',
#   'of',
#   'a',
#   'b',
#   'and',
#   'c',
#   'if',
#   '1a',
#   '1b',
#   '1c',
#   '1'],
#  ['why',
#   'is',
#   'bromine',
#   'such',
#   'a',
#   'commonly',
#   'used',
#   'component',
#   'in',
#   'fire',
#   'retardants'],
#  ['how', 'can', 'i', 'get', 'a', 'virtual', 'indian', 'phone', 'number'],
#  ['is', 'engineering', 'maths', 'difficult'],
#  ['how',
#   'many',
#   'candidates',
#   'appeared',
#   'in',
#   'ssc',
#   'cgl',
#   'tier',
#   '1',
# ...
#   'any',
#   'alternative',
#   'treatment',
#   'available',
#   'tnx'],
#  ['are', 'protein', 'powders', 'safe'],
#  ['what',
#   'are',
#   'the',
#   'advantages',
#   'of',
#   'xenotransplantation',
#   'what',
#   'are',
#   'the',
#   'disadvantages'],
#  ['what', 'makes', 'a', 'number', 'interesting'],
#  ['does',
#   'donald',
#   'trump',
#   'still',
#   'have',
#   'a',
#   'chance',
#   'of',
#   'winning',
#   'october',
#   '15',
#   '2016'],
#  ['online', 'auctions', 'how', 'does', 'bidherecom', 'work'],
#  ['i',
#   'am',
#   'using',
#   'a',
#   'windows',
#   '7',
#   'ultimate',
#   'genuine',
#   'copy',
#   'how',
#   'and',
#   'when',
#   'can',
#   'i',
#   'migrate',
#   'to',
#   'windows',
#   '10'],
#  ['how', 'much', 'pay', 'is', 'offered', 'after', 'mba', 'in', 'ib'],
#  ['what',
#   'large',
#   'companies',
#   'have',
#   'been',
#   'fined',
#   'by',
#   'ice',
#   'for',
#   'i9',
#   'noncompliance'],
#  ['i',
#   'am',
#   'a',
#   'man',
#   'age',
#   'is',
#   '32',
#   'and',
#   'i',
#   'see',
#   'my',
#   'breast',
#   'is',
#   'growing'],
#  ['what', 'is', 'contrastive', 'divergence'],
#  ['how', 'can', 'i', 'forget', 'my', 'past', 'and', 'all', 'mistakes'],
#  ['what', 'is', 'a', 'good', 'seasoning', 'for', 'salmon'],
#  ['what', 'is', 'the', 'unit', 'used', 'to', 'describe', 'force'],
#  ['is', 'jio', 'sim', 'working', 'by', 'towers', 'or', 'satellite'],
#  ['can',
#   'i',
#   'share',
#   'this',
#   'video',
#   'with',
#   'my',
#   'indian',
#   'manager',
#   'or',
#   'would',
#   'he',
#   'fire',
#   'me'],
#  ['can',
#   'i',
#   'shrink',
#   'my',
#   'oversized',
#   'sweater',
#   'by',
#   'washing',
#   'it',
#   'in',
#   'hot',
#   'water'],
#  ['what',
#   'is',
#   'the',
#   'origin',
#   'and',
#   'original',
#   'meaning',
#   'of',
#   'falana',
#   'dimka'],
#  ['how',
#   'can',
#   'a',
#   'rising',
#   'computer',
#   'science',
#   'student',
#   'who',
#   'has',
#   'had',
#   'no',
#   'prior',
#   'knowledge',
#   'of',
#   'programming',
#   'or',
#   'data',
#   'structures',
#   'learn',
#   'to',
#   'compete',
#   'against',
#   'other',
#   'computer',
#   'science',
#   'students',
#   'with',
#   'years',
#   'of',
#   'experience'],
#  ['is', 'michele', 'obama', 'really', 'a', 'man'],
#  ['how', 'do', 'i', 'flirt', 'with', 'a', 'girl', 'who', 'likes', 'me'],
#  ['can', 'chihuahuas', 'eat', 'peanuts', 'why', 'or', 'why', 'not'],
#  ['for',
#   'how',
#   'long',
#   'will',
#   'donald',
#   'trump',
#   'be',
#   'president',
#   'of',
#   'the',
#   'us'],
#  ['for',
#   'building',
#   'a',
#   'system',
#   'like',
#   'udemy',
#   'coursera',
#   'or',
#   'edx',
#   'can',
#   'one',
#   'use',
#   'an',
#   'available',
#   'off',
#   'the',
#   'shelf',
#   'lms',
#   'or',
#   'have',
#   'this',
#   'custom',
#   'build',
#   'in',
#   'php',
#   'or',
#   'dot',
#   'net'],
#  ['how',
#   'can',
#   'i',
#   'tell',
#   'if',
#   'a',
#   'guy',
#   'is',
#   'gay',
#   'and',
#   'is',
#   'interested',
#   'in',
#   'me'],
#  ['whats', 'a', 'good', 'distributed', 'queue'],
#  ['how',
#   'do',
#   'i',
#   'get',
#   'a',
#   'job',
#   'in',
#   'whatsapp',
#   'as',
#   'a',
#   'support',
#   'analyst'],
#  ['how', 'do', 'you', 'heal', 'a', 'cut', 'on', 'your', 'gums'],
#  ['why', 'are', 'converse', 'shoes', 'sized', 'so', 'large'],
#  ['who', 'made', 'you', 'realize', 'you', 'were', 'gay'],
#  ['what',
#   'is',
#   'your',
#   'preferred',
#   'combination',
#   'of',
#   'sauces',
#   'in',
#   'subway'],
#  ['what',
#   'is',
#   'the',
#   'difference',
#   'between',
#   'single',
#   'phase',
#   'and',
#   'three',
#   'phase',
#   'power'],
#  ['what', 'are', 'the', 'components', 'for', 'an', 'online', 'business'],
#  ['why',
#   'does',
#   'a',
#   'girl',
#   'ignore',
#   'you',
#   'when',
#   'she',
#   'knows',
#   'the',
#   'fact',
#   'that',
#   'you',
#   'like',
#   'her'],
#  ['what', 'will', 'happen', 'after', 'death', 'according', 'to', 'science'],
#  ['how', 'can', 'i', 'write', 'research'],
#  ['how',
#   'do',
#   'i',
#   'perform',
#   'reverse',
#   'engineering',
#   'in',
#   'pharmaceuticals'],
#  ['how',
#   'do',
#   'i',
#   'apply',
#   'for',
#   'pan',
#   'card',
#   'online',
#   'please',
#   'read',
#   'details'],
#  ['what',
#   'are',
#   'some',
#   'of',
#   'the',
#   'best',
#   'evidence',
#   'that',
#   'we',
#   'really',
#   'did',
#   'land',
#   'on',
#   'the',
#   'moon'],
#  ['who',
#   'is',
#   'the',
#   'famous',
#   'coder',
#   'trojenguri',
#   'from',
#   'svnit',
#   'surat'],
#  ['why',
#   'is',
#   'frictional',
#   'force',
#   'is',
#   'not',
#   'a',
#   'conservative',
#   'force'],
#  ['i',
#   'got',
#   'suspended',
#   'from',
#   'upwork',
#   'do',
#   'i',
#   'have',
#   'the',
#   'legal',
#   'right',
#   'to',
#   'create',
#   'another',
#   'account'],
#  ['what',
#   'is',
#   'the',
#   'process',
#   'to',
#   'becoming',
#   'a',
#   'lawyer',
#   'in',
#   'the',
#   'us'],
#  ['how',
#   'do',
#   'we',
#   'challenge',
#   'our',
#   'freeholder',
#   'if',
#   'we',
#   'suspect',
#   'they',
#   'are',
#   'overcharging',
#   'us',
#   'for',
#   'building',
#   'work'],
#  ['muslim',
#   'women',
#   'what',
#   'emotions',
#   'does',
#   'an',
#   'unmarried',
#   'muslima',
#   'from',
#   'an',
#   'orthodox',
#   'family',
#   'experience',
#   'while',
#   'being',
#   'undressed',
#   'for',
#   'her',
#   'first',
#   'sexual',
#   'intercourse'],
#  ['would',
#   'ramzor',
#   'in',
#   'the',
#   'original',
#   'hebrew',
#   'but',
#   'with',
#   'english',
#   'or',
#   'other',
#   'subtitles',
#   'work',
#   'on',
#   'cable',
#   'or',
#   'broadcast',
#   'tv',
#   'has',
#   'anyone',
#   'tried'],
#  ['what',
#   'are',
#   'the',
#   'best',
#   'activities',
#   'to',
#   'do',
#   'with',
#   'children',
#   'when',
#   'visiting',
#   'silchar',
#   'assam',
#   'india'],
#  ['my',
#   'linkedin',
#   'account',
#   'has',
#   'been',
#   'restricted',
#   'how',
#   'can',
#   'i',
#   'get',
#   'them',
#   'to',
#   'unrestrict',
#   'release',
#   'my',
#   'linkedin',
#   'account'],
#  ['what', 'does', '押一付三', '，', '先付后用', 'mean', 'in', 'english'],
#  ['what', 'is', 'the', 'origin', 'of', 'the', 'term', 'hoosier'],
#  ['how',
#   'the',
#   'internal',
#   'working',
#   'of',
#   'statementbasedreplication',
#   'happens',
#   'on',
#   'secondary',
#   'node',
#   'of',
#   'mongodb'],
#  ['what',
#   'consumer',
#   'electronics',
#   'segments',
#   'are',
#   'growing',
#   'the',
#   'fastest'],
#  ['what',
#   'should',
#   'i',
#   'do',
#   'if',
#   'the',
#   'white',
#   'part',
#   'of',
#   'my',
#   'eye',
#   'is',
#   'swollen'],
#  ['what',
#   'are',
#   'we',
#   'sensing',
#   'when',
#   'we',
#   'feel',
#   'someones',
#   'presence'],
#  ['how', 'is', 'a', 'compiler', 'program', 'compiled'],
#  ['trump',
#   'supporters',
#   'cite',
#   'a',
#   'shakeup',
#   'of',
#   'dc',
#   'as',
#   'a',
#   'primary',
#   'driver',
#   'to',
#   'success',
#   'change',
#   'the',
#   'outcome',
#   'expected',
#   'so',
#   'why',
#   'did',
#   '435',
#   'party',
#   'wag',
#   'house',
#   'members',
#   'get',
#   'in'],
#  ['does',
#   'a',
#   'long',
#   'sleeve',
#   'shirt',
#   'look',
#   'good',
#   'under',
#   'a',
#   'polo',
#   'shirt'],
#  ['its',
#   '2016',
#   'dad',
#   'says',
#   'that',
#   'he',
#   'and',
#   'ma',
#   'will',
#   'leave',
#   'the',
#   'country',
#   'if',
#   'hillary',
#   'is',
#   'elected',
#   'they',
#   'are',
#   'big',
#   'republicans',
#   'what',
#   'conservative',
#   'country',
#   'should',
#   'they',
#   'move',
#   'to'],
#  ['what', 'are', 'some', 'mindblowing', 'facts', 'about', 'netherlands'],
#  ['how', 'do', 'i', 'prepare', 'for', 'a', 'travel', 'quiz'],
#  ['what', 'is', 'all', 'about', 'scholarships', 'for', 'engineering'],
#  ['what',
#   'universities',
#   'does',
#   'petmeds',
#   'recruit',
#   'new',
#   'grads',
#   'from',
#   'what',
#   'majors',
#   'are',
#   'they',
#   'looking',
#   'for'],
#  ['what',
#   'did',
#   'chinese',
#   'soldiers',
#   'in',
#   'general',
#   'think',
#   'of',
#   'americans',
#   'soldiers',
#   'in',
#   'the',
#   'korean',
#   'war'],
#  ['how',
#   'do',
#   'i',
#   'get',
#   'the',
#   'best',
#   'employment',
#   'attorney',
#   'in',
#   'los',
#   'angeles'],
#  ['whats', 'the', 'most', 'sophisticated', 'indian', 'city'],
#  ['what',
#   'percentage',
#   'of',
#   'quora',
#   'questions',
#   'do',
#   'you',
#   'think',
#   'could',
#   'be',
#   'answered',
#   'with',
#   'a',
#   'simple',
#   'google',
#   'search'],
#  ['how', 'do', 'i', 'cook', 'a', 'steak', 'like', 'a', 'restaurant', 'does'],
#  ['where', 'can', 'i', 'find', 'indoor', 'badminton', 'courts', 'to', 'play'],
#  ['is', 'it', 'safe', 'to', 'travel', 'to', 'turkey', 'in', '2016'],
#  ['whats', 'brendan', 'frasers', 'political', 'beliefs'],
#  ['when', 'is', 'ekstopcom', 'launching', 'in', 'pune'],
#  ['why', 'dont', 'most', 'american', 'eat', 'chicken', 'livers'],
#  ['how',
#   'do',
#   'you',
#   'eat',
#   'good',
#   'tasting',
#   'food',
#   'while',
#   'eating',
#   'healthy'],
#  ['what',
#   'are',
#   'the',
#   'benefits',
#   'and',
#   'tradeoffs',
#   'of',
#   'pair',
#   'programming'],
#  ['how', 'good', 'are', 'larry', 'sergey', 'at', 'programming'],
#  ['do', 'younger', 'women', 'really', 'like', 'older', 'men'],
#  ['i',
#   'want',
#   'to',
#   'hire',
#   'a',
#   'hacker',
#   'to',
#   'hack',
#   'the',
#   'balance',
#   'of',
#   'an',
#   'emv',
#   'stored',
#   'value',
#   'card',
#   'where',
#   'should',
#   'i',
#   'go'],
#  ['my',
#   'facebook',
#   'is',
#   'hacked',
#   'by',
#   'someone',
#   'how',
#   'can',
#   'i',
#   'get',
#   'back',
#   'the',
#   'old',
#   'facebook',
#   'account'],
#  ['where',
#   'can',
#   'i',
#   'get',
#   'quality',
#   'services',
#   'in',
#   'australia',
#   'for',
#   'full',
#   'color',
#   'printed',
#   'pvc',
#   'sticker'],
#  ['is', 'gwern', 'a', 'buddha'],
#  ['why',
#   'was',
#   'jaqen',
#   'hghar',
#   'captured',
#   'in',
#   'the',
#   'first',
#   'place',
#   'with',
#   'the',
#   'other',
#   'two',
#   'prisoners',
#   'if',
#   'he',
#   'has',
#   'such',
#   'skills'],
#  ['what',
#   'is',
#   'your',
#   'review',
#   'of',
#   'university',
#   'of',
#   'north',
#   'carolina',
#   'at',
#   'charlotte'],
#  ['how',
#   'should',
#   'i',
#   'start',
#   'learning',
#   'python',
#   'for',
#   'data',
#   'science'],
#  ['why', 'is', 'adoption', 'so', 'expensive'],
#  ['who', 'is', 'redditceo', 'on', 'reddit'],
#  ['what',
#   'is',
#   'the',
#   'best',
#   'way',
#   'to',
#   'send',
#   'money',
#   'from',
#   'australia',
#   'to',
#   'the',
#   'philippines'],
#  ['what',
#   'are',
#   'computer',
#   'ethics',
#   'and',
#   'what',
#   'are',
#   'some',
#   'examples'],
#  ['what',
#   'is',
#   'the',
#   'advantage',
#   'of',
#   'brands',
#   'for',
#   'using',
#   'media',
#   'buyers',
#   'to',
#   'purchase',
#   'advertising',
#   'space',
#   'for',
#   'them'],
#  ['can', 'i', 'take', 'two', 'tylenol', 'and', 'advil', 'together'],
#  ['what',
#   'would',
#   'happen',
#   'if',
#   'a',
#   'very',
#   'large',
#   'number',
#   'of',
#   'people',
#   'went',
#   'to',
#   'the',
#   'bank',
#   'to',
#   'take',
#   'back',
#   'their',
#   'deposits',
#   'simultaneously'],
#  ['what', 'are', 'basics', 'needed', 'for', 'angular', 'js'],
#  ['what',
#   'is',
#   'exactly',
#   'the',
#   'concept',
#   'of',
#   'tradeoff',
#   'in',
#   'evolutionary',
#   'biology'],
#  ['how', 'do', 'we', 'develop', 'tamil', 'nadu'],
#  ['why',
#   'does',
#   'the',
#   'brain',
#   'not',
#   'start',
#   'recording',
#   'memory',
#   'for',
#   'the',
#   'first',
#   'few',
#   'years',
#   'of',
#   'life'],
#  ['how',
#   'can',
#   'government',
#   'get',
#   'an',
#   'economy',
#   'out',
#   'of',
#   'a',
#   'recession',
#   'with',
#   'fiscal',
#   'policy'],
#  ['can',
#   'you',
#   'put',
#   'some',
#   'tutorials',
#   'for',
#   'learning',
#   'adobe',
#   'illustrator'],
#  ['which',
#   'compiler',
#   'i',
#   'can',
#   'use',
#   'in',
#   'windows',
#   '81',
#   'for',
#   'c',
#   'language'],
#  ['who',
#   'is',
#   'the',
#   'biggest',
#   'traitor',
#   'in',
#   'the',
#   'history',
#   'of',
#   'portugal'],
#  ['what', 'are', 'some', 'good', 'quotation', 'on', 'faith'],
#  ['is',
#   'it',
#   'very',
#   'useful',
#   'for',
#   'students',
#   'go',
#   'abroad',
#   'for',
#   'study'],
#  ['how', 'are', 'the', 'job', 'opportunities', 'in', 'usa'],
#  ['what',
#   'should',
#   'your',
#   'annual',
#   'income',
#   'be',
#   'to',
#   'fly',
#   'first',
#   'class'],
#  ['how', 'do', 'you', 'make', 'a', 'flip', 'flop', 'at', 'home'],
#  ['my',
#   'stepdad',
#   'let',
#   'me',
#   'have',
#   'facebook',
#   'but',
#   'my',
#   'mother',
#   'wouldnt',
#   'approve'],
#  ['what',
#   'are',
#   'the',
#   'best',
#   'aspects',
#   'of',
#   'living',
#   'in',
#   'batna',
#   'algeria',
#   'as',
#   'a',
#   'young',
#   'adult'],
#  ['how',
#   'many',
#   'times',
#   'do',
#   'artists',
#   'act',
#   'out',
#   'or',
#   'get',
#   'someone',
#   'to',
#   'act',
#   'out',
#   'a',
#   'particular',
#   'pose',
#   'that',
#   'they',
#   'wish',
#   'to',
#   'draw'],
#  ['what',
#   'should',
#   'you',
#   'do',
#   'if',
#   'you',
#   'have',
#   'a',
#   'personality',
#   'disorder',
#   'and',
#   'you',
#   'are',
#   'tired',
#   'of',
#   'hurting',
#   'other',
#   'people'],
#  ['can', 'rbi', 'print', 'unlimited', 'currency'],
#  ['should', 'air', 'india', 'be', 'privatised'],
#  ['what', 'human', 'food', 'is', 'very', 'healthy', 'for', 'dogs'],
#  ['why', 'do', 'atms', 'eat', 'cards'],
#  ['is', 'asianet', 'owned', 'by', 'news', 'corp'],
#  ['what', 'is', 'it', 'like', 'to', 'testdrive', 'a', 'selfdriving', 'car'],
#  ['why', 'do', 'human', 'beings', 'sleep', 'at', 'night'],
#  ['what',
#   'are',
#   'the',
#   'pros',
#   'and',
#   'cons',
#   'of',
#   'raising',
#   'kids',
#   'in',
#   'england',
#   'for',
#   'indian',
#   'parents'],
#  ['i',
#   'am',
#   'a',
#   'iit',
#   'jee',
#   'repeater',
#   'and',
#   'i',
#   'dont',
#   'get',
#   'time',
#   'for',
#   'revision',
#   'of',
#   'previous',
#   'chapters',
#   'taught',
#   'in',
#   'coaching',
#   'because',
#   'of',
#   'lot',
#   'of',
#   'homework',
#   'what',
#   'should',
#   'i',
#   'do'],
#  ['three',
#   'balls',
#   'are',
#   'drawn',
#   'from',
#   'a',
#   'bag',
#   'containing',
#   '5',
#   'white',
#   '4',
#   'black',
#   'and',
#   '6',
#   'red',
#   'balls',
#   'find',
#   'the',
#   'probability',
#   'that',
#   'all',
#   'the',
#   'balls',
#   'are',
#   'of',
#   'one',
#   'colors'],
#  ['should',
#   'a',
#   'teacher',
#   'who',
#   'is',
#   'gay',
#   'bi',
#   'or',
#   'trans',
#   'be',
#   'forced',
#   'to',
#   'inform',
#   'his',
#   'or',
#   'her',
#   'class',
#   'of',
#   'this',
#   'by',
#   'the',
#   'school'],
#  ['in',
#   'what',
#   'programming',
#   'language',
#   'are',
#   'chrome',
#   'extensions',
#   'written',
#   'what',
#   'do',
#   'i',
#   'need',
#   'to',
#   'know',
#   'to',
#   'start',
#   'coding',
#   'them'],
#  ['is', 'there', 'a', 'tibetan', 'market', 'in', 'bangalore'],
#  ['does',
#   'blocking',
#   'somebody',
#   'on',
#   'snapchat',
#   'clear',
#   'saved',
#   'messages'],
#  ['i',
#   'am',
#   'in',
#   '10th',
#   'how',
#   'can',
#   'i',
#   'get',
#   'admission',
#   'in',
#   'the',
#   'indian',
#   'institute',
#   'of',
#   'science'],
#  ['why', 'would', 'you', 'buy', 'an', 'iphone', '7'],
#  ['what',
#   'type',
#   'of',
#   'government',
#   'does',
#   'turkey',
#   'have',
#   'how',
#   'does',
#   'it',
#   'compare',
#   'to',
#   'the',
#   'one',
#   'in',
#   'brazil'],
#  ['what',
#   'are',
#   'the',
#   'best',
#   'job',
#   'interview',
#   'questions',
#   'youve',
#   'ever',
#   'asked',
#   'or',
#   'been',
#   'asked'],
#  ['how', 'many', 'points', 'are', 'in', 'a', 'gram', 'of', 'meth'],
#  ['which', 'kpop', 'idols', 'are', 'not', 'koreans'],
#  ['what',
#   'is',
#   'the',
#   'best',
#   'dress',
#   'code',
#   'for',
#   'a',
#   'software',
#   'engineer'],
#  ['what',
#   'are',
#   'some',
#   'of',
#   'the',
#   'security',
#   'concerns',
#   'about',
#   'yammer'],
#  ['donald',
#   'trump',
#   'why',
#   'wouldnt',
#   'you',
#   'vote',
#   'for',
#   'donald',
#   'trump',
#   'for',
#   'president'],
#  ['i',
#   'am',
#   '25',
#   'working',
#   'in',
#   'digital',
#   'marketing',
#   '9',
#   'hours',
#   'a',
#   'day',
#   'i',
#   'want',
#   'to',
#   'spend',
#   'another',
#   '5',
#   'to',
#   '8',
#   'hours',
#   'for',
#   'myself',
#   'at',
#   'home',
#   'to',
#   'work',
#   'on',
#   'my',
#   'startup',
#   'it',
#   'is',
#   'healthy',
#   'to',
#   'spend',
#   '15',
#   'to',
#   '18',
#   'hours',
#   'daily',
#   'for',
#   'work'],
#  ['what',
#   'are',
#   'the',
#   'craziestweirdest',
#   'things',
#   'youve',
#   'seen',
#   'a',
#   'lion',
#   'do'],
#  ['what', 'has', 'gone', 'wrong', 'at', 'chelsea', 'fc'],
#  ['how', 'do', 'i', 'control', 'someone', 'who', 'is', 'very', 'dominating'],
#  ['what',
#   'is',
#   'an',
#   'easy',
#   'way',
#   'to',
#   'clean',
#   'toothpaste',
#   'stains',
#   'from',
#   'a',
#   'shirt',
#   'without',
#   'washing',
#   'it'],
#  ['job',
#   'interviews',
#   'should',
#   'someone',
#   'with',
#   'aspergers',
#   'disclose',
#   'their',
#   'aspergers',
#   'in',
#   'a',
#   'job',
#   'interview'],
#  ['should', 'quora', 'allow', 'the', 'option', 'to', 'bookmark', 'questions'],
#  ['what',
#   'is',
#   'the',
#   'easiest',
#   'and',
#   'safest',
#   'way',
#   'to',
#   'make',
#   'meth'],
#  ['which', 'is', 'the', 'best', 'book', 'for', 'control', 'system'],
#  ['what',
#   'do',
#   'you',
#   'call',
#   'someone',
#   'who',
#   'is',
#   'attracted',
#   'to',
#   'women',
#   'but',
#   'doesnt',
#   'want',
#   'to',
#   'have',
#   'sex',
#   'with',
#   'them',
#   'or',
#   'be',
#   'in',
#   'a',
#   'relationship',
#   'with',
#   'them'],
#  ...]

# %% [markdown]
# Несколько проверок:

# %%
assert all(
    isinstance(row, (list, tuple)) for row in data_tok
), "please convert each line into a list of tokens (strings)"
assert all(
    all(isinstance(tok, str) for tok in row) for row in data_tok
), "please convert each line into a list of tokens (strings)"
is_latin = lambda tok: all("a" <= x.lower() <= "z" for x in tok)
assert all(
    map(lambda l: not is_latin(l) or l.islower(), map(" ".join, data_tok))
), "please make sure to lowercase the data"

# %% [markdown]
# Ниже заданы константы ширины окна контекста и проведена предобработка для построения skip-gram модели.

# %%
min_count = 5
window_radius = 5

# %%
vocabulary_with_counter = Counter(chain.from_iterable(data_tok))

word_count_dict = dict()
for word, counter in vocabulary_with_counter.items():
    if counter >= min_count:
        word_count_dict[word] = counter

vocabulary = set(word_count_dict.keys())
del vocabulary_with_counter

# %%
word_to_index = {word: index for index, word in enumerate(vocabulary)}
index_to_word = {index: word for word, index in word_to_index.items()}

# %% [markdown]
# Пары `(слово, контекст)` на основе доступного датасета сгенерированы ниже.

# %%
context_pairs = []

for text in data_tok:
    for i, central_word in enumerate(text):
        context_indices = range(
            max(0, i - window_radius), min(i + window_radius, len(text))
        )
        for j in context_indices:
            if j == i:
                continue
            context_word = text[j]
            if central_word in vocabulary and context_word in vocabulary:
                context_pairs.append(
                    (word_to_index[central_word], word_to_index[context_word])
                )

print(f"Generated {len(context_pairs)} pairs of target and context words.")
# Out:
# Generated 40220313 pairs of target and context words.

# %%
index_to_word[context_pairs[1][1]]
# Out:
# 'get'

# %% [markdown]
# #### Подзадача №1: subsampling
# Для того, чтобы сгладить разницу в частоте встречаемсости слов, необходимо реализовать механизм subsampling'а.
# Для этого вам необходимо реализовать функцию ниже.
#
# Вероятность **исключить** слово из обучения (на фиксированном шаге) вычисляется как
# $$
# P_\text{drop}(w_i)=1 - \sqrt{\frac{t}{f(w_i)}},
# $$
# где $f(w_i)$ – нормированная частота встречаемости слова, а $t$ – заданный порог (threshold).

# %%
import numpy as np
def subsample_frequent_words(word_count_dict:dict, threshold=1e-5):
    """
    Calculates the subsampling probabilities for words based on their frequencies.

    This function is used to determine the probability of keeping a word in the dataset
    when subsampling frequent words. The method used is inspired by the subsampling approach
    in Word2Vec, where each word's frequency affects its probability of being kept.

    Parameters:
    - word_count_dict (dict): A dictionary where keys are words and values are the counts of those words.
    - threshold (float, optional): A threshold parameter used to adjust the frequency of word subsampling.
                                   Defaults to 1e-5.

    Returns:
    - dict: A dictionary where keys are words and values are the probabilities of keeping each word.

    Example:
    >>> word_counts = {'the': 5000, 'is': 1000, 'apple': 50}
    >>> subsample_frequent_words(word_counts)
    {'the': 0.028, 'is': 0.223, 'apple': 1.0}
    """
    sum_words = np.sum(list(word_count_dict.values()))
    print(sum_words)
    ### YOUR CODE HERE
    keep_prob_dict = {
        word: max(np.sqrt(threshold / (word_count_dict[word] / sum_words)), 0) for word in word_count_dict.keys()
    }  # THIS IS A PLACEHOLDER!
    return keep_prob_dict

# %%
word_counts = {'the': 5000, 'is': 1000, 'apple': 50}

# %%
subsample_frequent_words(word_counts)
# Out:
# 6050
# {'the': 0.0034785054261852176,
#  'is': 0.007778174593052023,
#  'apple': 0.034785054261852175}

# %% [markdown]
# #### Подзадача №2: negative sampling
# Для более эффективного обучения необходимо не только предсказывать высокие вероятности для слов из контекста, но и предсказывать низкие для слов, не встреченных в контексте. Для этого вам необходимо вычислить вероятност использовать слово в качестве negative sample, реализовав функцию ниже.
#
# В оригинальной статье предлагается оценивать вероятность слов выступать в качестве negative sample согласно распределению $P_n(w)$
# $$
# P_n(w) = \frac{U(w)^{3/4}}{Z},
# $$
#
# где $U(w)$ распределение слов по частоте (или, как его еще называют, по униграммам), а $Z$ – нормировочная константа, чтобы общая мера была равна $1$.

# %%
def get_negative_sampling_prob(word_count_dict):
    """
    Calculates the negative sampling probabilities for words based on their frequencies.

    This function adjusts the frequency of each word raised to the power of 0.75, which is
    commonly used in algorithms like Word2Vec to moderate the influence of very frequent words.
    It then normalizes these adjusted frequencies to ensure they sum to 1, forming a probability
    distribution used for negative sampling.

    Parameters:
    - word_count_dict (dict): A dictionary where keys are words and values are the counts of those words.

    Returns:
    - dict: A dictionary where keys are words and values are the probabilities of selecting each word
            for negative sampling.

    Example:
    >>> word_counts = {'the': 5000, 'is': 1000, 'apple': 50}
    >>> get_negative_sampling_prob(word_counts)
    {'the': 0.298, 'is': 0.160, 'apple': 0.042}
    """

    ### YOUR CODE HERE
    sum_words = np.sum(list(word_count_dict.values()))
    Z = np.sum((word_count_dict[word] / sum_words) ** 0.75 for word in word_count_dict.keys())
    #print(Z)
    negative_sampling_prob_dict = {
        word: ((word_count_dict[word] / sum_words) ** 0.75) / Z for word in word_count_dict.keys()
    }  # THIS IS A PLACEHOLDER!
    return negative_sampling_prob_dict

# %%
word_counts = {'the': 5000, 'is': 1000, 'apple': 50}
get_negative_sampling_prob(word_counts)
# Out:
# C:\Users\VIKTOR\AppData\Local\Temp\ipykernel_7304\962603389.py:25: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   Z = np.sum((word_count_dict[word] / sum_words) ** 0.75 for word in word_count_dict.keys())
# {'the': 0.751488398196177,
#  'is': 0.22474745206890812,
#  'apple': 0.023764149734914898}

# %% [markdown]
# Для удобства, преобразуем полученные словари в массивы (т.к. все слова все равно уже пронумерованы).

# %%
keep_prob_dict = subsample_frequent_words(word_count_dict)
assert keep_prob_dict.keys() == word_count_dict.keys()
# Out:
# 6010862

# %%
keep_prob_dict
# Out:
# {'can': 0.02911670312402145,
#  'i': 0.020518199702878066,
#  'get': 0.048266978094480766,
#  'back': 0.13981244114594021,
#  'with': 0.04543547424212828,
#  'my': 0.03648711297249418,
#  'ex': 0.2694345035269634,
#  'even': 0.15287374210909657,
#  'though': 0.2928258210670549,
#  'she': 0.13437283533713018,
#  'is': 0.018017218948841916,
#  'pregnant': 0.2761882955870675,
#  'another': 0.18570332727278635,
#  'guys': 0.23197532514724706,
#  'baby': 0.3118703883964877,
#  'what': 0.017055990497688175,
#  'are': 0.02477165792788909,
#  'some': 0.046858816414833686,
#  'ways': 0.1315008302423615,
#  'to': 0.020611014394515556,
#  'overcome': 0.2724117707433109,
#  'a': 0.01971236185129397,
#  'fast': 0.24541613263254033,
#  'food': 0.16597436110020564,
#  'addiction': 0.49941301644615815,
#  'who': 0.05910385377849528,
#  'were': 0.11093805592425104,
#  'the': 0.015446042678242946,
#  'great': 0.18284097772878674,
#  'chinese': 0.1907494775775963,
#  'soldiers': 0.5337368043364796,
#  'and': 0.026000157449729635,
#  'leaders': 0.5495938198653355,
#  'fought': 0.7137191918014835,
#  'in': 0.02078127367685705,
#  'ww2': 0.5482181135278185,
#  'zip': 0.9136968558796974,
#  'codes': 0.563945942848272,
#  'bay': 0.43005767055128785,
#  'area': 0.23858131038844319,
#  'why': 0.032731043758418905,
#  'was': 0.07163954960987688,
#  'george': 0.46752197809300905,
#  'rr': 2.2380910764905586,
#  'martin': 0.6934471573234691,
#  'critical': 0.6309281505257376,
#  'of': 0.023173997029478956,
#  'jk': 1.0269066135644742,
#  'rowling': 1.241469559299247,
#  'after': 0.07660832960462956,
#  'losing': 0.3796648149389642,
#  'hugo': 2.5843249709654463,
#  'award': 0.7639233174550024,
#  'do': 0.024024904896217184,
#  'improve': 0.1678699460886685,
#  'immune': 0.9471766372169197,
#  'system': 0.14238230842978444,
#  'how': 0.02107705122410507,
#  'your': 0.05405691197821349,
#  'relationship': 0.1748989093697492,
#  'mother': 0.3038630441761147,
#  'law': 0.1984032857217837,
#  'does': 0.038970991620462477,
#  'one': 0.06714357159460733,
#  'free': 0.1269956023483901,
#  'psn': 1.880372616390323,
#  'review': 0.189040728802696,
#  'look': 0.16219044914639924,
#  'smart': 0.2694345035269634,
#  'act': 0.30742545243527164,
#  'which': 0.04554352918725021,
#  'brand': 0.2913746399242056,
#  'should': 0.04766843706940449,
#  'go': 0.10590744726272222,
#  'gtx': 0.8614416569884822,
#  '960': 3.165138754199148,
#  'graphic': 0.4568484279398487,
#  'card': 0.14926136399389997,
#  'msi': 1.582569377099574,
#  'zotac': 3.165138754199148,
#  'or': 0.04284065440171685,
#  'asus': 0.611020020816429,
#  'code': 0.19000335068959515,
#  'india': 0.05804907435158167,
#  'as': 0.05984222130486159,
#  'an': 0.046350271728852165,
#  'indian': 0.09553390177999986,
#  'doctor': 0.3038630441761147,
#  'practicing': 0.8360247854342987,
#  'own': 0.15809234386645418,
#  'private': 0.22390241976803568,
#  'clinic': 1.036034851868273,
#  'earn': 0.1812353178526704,
#  'more': 0.08836482573176,
#  'other': 0.09229078074373225,
#  'sources': 0.4521626791713068,
#  'income': 0.2709108680224889,
#  'use': 0.07973712628524633,
#  'windows': 0.17652339231742467,
#  'only': 0.12260062287028581,
#  'os': 0.34500285549112447,
#  'that': 0.04614866019581155,
#  'not': 0.0627652948597036,
#  'based': 0.214452239008149,
#  'on': 0.039862765880326,
#  'unix': 0.8952364305962234,
#  'linux': 0.2861675258673413,
#  'avoid': 0.2671851600271193,
#  'using': 0.11547193008298433,
#  'facebook': 0.12714921579358276,
#  'you': 0.03196131694572043,
#  'norton': 1.880372616390323,
#  'security': 0.2546411058183341,
#  'renewal': 1.370545283819546,
#  'emc': 2.2380910764905586,
#  'plan': 0.23104638796687554,
#  'lightweight': 1.6166070211617805,
#  'web': 0.1631934031783739,
#  'client': 0.5112160268291249,
#  'for': 0.02835849089296341,
#  'where': 0.06978434622843681,
#  'strangest': 0.7495083746952517,
#  'place': 0.1667788578124776,
#  'youve': 0.23679415930422992,
#  'ever': 0.09835981469394928,
#  'masturbated': 1.9382437282240847,
#  'tamil': 0.3202724416181765,
#  'nadu': 0.5350060969835052,
#  'we': 0.06951174459511103,
#  'learn': 0.09126833260548461,
#  'from': 0.048793670449290553,
#  'cm': 0.492314399283563,
#  'car': 0.1468587726456207,
#  'buy': 0.11277725509995273,
#  'out': 0.09597941988856566,
#  'kwid': 2.3376098904650453,
#  'figo': 2.150288352756439,
#  'any': 0.06902791430163546,
#  'discovered': 0.47270722329906045,
#  'plate': 0.699062205729701,
#  'tectonics': 2.2380910764905586,
#  'earth': 0.17186449722210054,
#  'planet': 0.3443217040754705,
#  'has': 0.07946859384070089,
#  'life': 0.08318757534444536,
#  'it': 0.03435197390252651,
#  'ride': 0.5552020653179645,
#  'civilian': 1.1190455382452793,
#  'entertainment': 0.7325872693016561,
#  'mean': 0.09718590723804539,
#  'experience': 0.15999976043423292,
#  'be': 0.04508381791070652,
#  'extra': 0.4446636073305421,
#  'show': 0.1916799683559778,
#  'met': 0.3683549544400029,
#  'will': 0.05981728036429246,
#  'run': 0.20159710521978055,
#  'well': 0.2015289865811676,
#  'enough': 0.24180864383529188,
#  'excel': 0.4025144018116224,
#  'outlook': 0.7229686384442364,
#  'vm': 1.7786544293221684,
#  'new': 0.09271877153503316,
#  '2015': 0.23429408207416844,
#  'macbook': 0.3038630441761147,
#  'true': 0.16023879553134499,
#  'ancient': 0.35313833054190724,
#  'china': 0.15789550750392234,
#  'had': 0.1319189579437624,
#  'no': 0.12272343845116496,
#  'glass': 0.3941058633470807,
#  'clear': 0.31677796714330647,
#  'ipad': 0.3783064391531843,
#  'mini': 0.573116396879015,
#  '2': 0.12371943501099485,
#  'purpose': 0.24665499024046994,
#  'steam': 0.5981550006159815,
#  'turbine': 0.7325872693016561,
#  'when': 0.05641250586040504,
#  'really': 0.11606562001218187,
#  'need': 0.11419971619490836,
#  'create': 0.17539051325314503,
#  'abstract': 0.7495083746952517,
#  'class': 0.17057022411686015,
#  'dogs': 0.2520709571566317,
#  'like': 0.05635882225821171,
#  'pets': 0.6552459734437791,
#  'drivers': 0.3610920409522281,
#  'within': 0.29035119229436646,
#  'rich': 0.29035119229436646,
#  'countries': 0.16601240679952486,
#  'less': 0.213474488144845,
#  'likely': 0.2928258210670549,
#  'slow': 0.3828921391774744,
#  'down': 0.2027657938811738,
#  'they': 0.07504909687350832,
#  'see': 0.13359258001355964,
#  'turn': 0.24880480522280263,
#  'signal': 0.4817464207439573,
#  'asian': 0.3413056894389703,
#  'girls': 0.1622259510509826,
#  'attracted': 0.3838294530382053,
#  'black': 0.14808595175156095,
#  'castor': 1.370545283819546,
#  'oil': 0.2389209280840488,
#  'hair': 0.16169585721110621,
#  'mumbai': 0.22160403803451467,
#  'cvs': 1.582569377099574,
#  'still': 0.1298490006636633,
#  'develop': 0.25900871296706823,
#  'film': 0.2660814101799393,
#  'always': 0.1850146518854674,
#  'print': 0.4293975662933482,
#  'money': 0.09664076540903431,
#  'fake': 0.29324444289775536,
#  'software': 0.13553820544213477,
#  'students': 0.16540679636587993,
#  'at': 0.05744047595143794,
#  'iit': 0.21619611942141131,
#  'foreign': 0.2371261914738252,
#  'internships': 0.5388690070539268,
#  'find': 0.09186221362612906,
#  'lifes': 1.880372616390323,
#  'goal': 0.45448743834689237,
#  'upcoming': 0.5580713457462273,
#  'mobiles': 0.9401863081951615,
#  'chemical': 0.25714994576989697,
#  'formula': 0.30670294743541543,
#  'hydrochloric': 1.036034851868273,
#  'acid': 0.33519033510479324,
#  'biggest': 0.22465314247713758,
#  'disneyland': 1.241469559299247,
#  'world': 0.10079003454230336,
#  'best': 0.03833411918796968,
#  'way': 0.07667573685885386,
#  'entrance': 0.3961585119363643,
#  'tickets': 0.47270722329906045,
#  'finance': 0.32617010600773544,
#  'credit': 0.23701535894079057,
#  'score': 0.19115489669081298,
#  'work': 0.08558076454236893,
#  'meet': 0.27308689388709817,
#  'hong': 0.47626146299283495,
#  'kong': 0.4683743433915283,
#  'atm': 0.5375720881891097,
#  'business': 0.11442336942748708,
#  'viable': 0.8893272146610842,
#  'speak': 0.2907592756894222,
#  'english': 0.13030670035800956,
#  'nonenglish': 1.7786544293221684,
#  'environment': 0.42808642562557164,
#  'high': 0.14749521667897475,
#  'school': 0.13545543401124446,
#  'student': 0.13851224911005877,
#  'internship': 0.27566405285768886,
#  'goldman': 0.8722778270682666,
#  'sachs': 0.9136968558796974,
#  'top': 0.14474484467245835,
#  'coaches': 1.0751441763782195,
#  'australia': 0.23483083897942328,
#  'wait': 0.3987700004106543,
#  'boys': 0.33708586577810173,
#  'propose': 0.6460812427413616,
#  'cricket': 0.31677796714330647,
#  'our': 0.1410798233493769,
#  'national': 0.2660814101799393,
#  'sport': 0.47898038972431645,
#  'hockey': 0.9136968558796974,
#  'tv': 0.170528958790475,
#  'shows': 0.2924089869467527,
#  'books': 0.12808275078258952,
#  'help': 0.1346765946773699,
#  'read': 0.14915084093987468,
#  'peoples': 0.453708538994104,
#  'body': 0.1782882057064469,
#  'language': 0.13643768947516582,
#  'this': 0.07375428202922905,
#  'cute': 0.611020020816429,
#  'girl': 0.11745583556095267,
#  'around': 0.18443787248253998,
#  'college': 0.12630278636232645,
#  'im': 0.10837228686151083,
#  'too': 0.17476555143242525,
#  'shy': 0.527523125699858,
#  'approach': 0.3553570225074751,
#  'her': 0.11670821182528351,
#  'acceptable': 0.6351484527628009,
#  'leave': 0.24504810023456913,
#  'note': 0.2668684021682398,
#  'feelings': 0.357618065610595,
#  'number': 0.12685952344260826,
#  'schools': 0.29819134280370535,
#  'apply': 0.18422946804029464,
#  'gre': 0.30409669514810583,
#  'solution': 0.2869504754177378,
#  'quickbooks': 1.036034851868273,
#  'error': 0.38103792905909317,
#  'think': 0.09206925648885397,
#  'aap': 0.628849304180597,
#  'fulfill': 1.329624228207088,
#  'promises': 1.107567844699477,
#  'mentioned': 0.6207347796496235,
#  'their': 0.08368523160658707,
#  'manifesto': 2.9303490772066243,
#  'all': 0.08882759310556787,
#  'pros': 0.24407471763763447,
#  'cons': 0.24347221186147291,
#  'having': 0.16219044914639924,
#  'dual': 0.4453967712370431,
#  'citizenship': 0.5168649941930893,
#  'someone': 0.09322008419408312,
#  'translate': 0.5157202198215068,
#  'italian': 0.5580713457462273,
#  'latin': 0.5145830183939063,
#  '“': 0.251143491883057,
#  'directive': 2.9303490772066243,
#  '”': 0.24703032140899522,
#  'density': 0.47716262077688637,
#  'volume': 0.4576436390341639,
#  'hole': 0.3443217040754705,
#  'las': 0.8722778270682666,
#  'vegas': 0.7530354924106756,
#  'possible': 0.11162583719292572,
#  'lick': 0.933348498841593,
#  'toad': 2.3376098904650453,
#  'president': 0.1585876735727119,
#  'linkedin': 0.40036190294948565,
#  'getting': 0.14675349752625233,
#  'connections': 0.826469902658288,
#  'so': 0.07293385292616089,
#  'now': 0.12298565184049359,
#  'job': 0.09520918876080725,
#  'record': 0.40692565027101063,
#  'facetime': 1.0269066135644742,
#  'call': 0.1981439349106302,
#  'mac': 0.2881370434378492,
#  'application': 0.22224044068476842,
#  'binary': 0.5180174259341365,
#  'search': 0.24180864383529188,
#  'trees': 0.6309281505257376,
#  'symptoms': 0.43005767055128785,
#  'persist': 2.072069703736546,
#  'know': 0.0849976102605244,
#  'digital': 0.25127536035729625,
#  'marketing': 0.19698931490620897,
#  'agencies': 0.5963826856074107,
#  '128gb': 1.9382437282240847,
#  'micro': 0.6879652756298394,
#  'sd': 0.5428168181248769,
#  'cards': 0.3033973534132969,
#  'capacity': 0.5827492798484112,
#  'reduced': 0.7954384424890927,
#  'showed': 1.1190455382452793,
#  'but': 0.08716711784887195,
#  'said': 0.25519227768792163,
#  'ubuntu': 0.4658311154902008,
#  'did': 0.0704437585873756,
#  'visit': 0.21781113155484694,
#  'vietnam': 0.4718310275072195,
#  'there': 0.05949761207113489,
#  'nobel': 0.6227339306534507,
#  'prize': 0.6017475554432504,
#  'winners': 1.392475400836756,
#  'quora': 0.09046331090264731,
#  'alternatives': 0.4658311154902008,
#  'love': 0.10940319984079178,
#  'most': 0.06971096327580628,
#  'precious': 1.241469559299247,
#  'thing': 0.13347374300263026,
#  'download': 0.18737709367381292,
#  'cool': 0.3591496275031095,
#  'stuff': 0.4983801032071077,
#  'iphone': 0.14517559614718323,
#  'have': 0.044602282017236816,
#  'cydia': 2.741090567639092,
#  'cause': 0.2110874452984805,
#  'jailbroken': 2.2380910764905586,
#  'start': 0.10027448111257146,
#  'investing': 0.37431715607667965,
#  'stocks': 0.38103792905909317,
#  '100': 0.24504810023456913,
#  '€': 1.225852968344899,
#  'quantitative': 0.6748098497601627,
#  'analysis': 0.32969002922549123,
#  'applied': 0.42108379619955566,
#  'process': 0.17131816047744325,
#  'guest': 0.7676589060764106,
#  'speaker': 0.44320807606902934,
#  'npr': 2.5843249709654463,
#  'cant': 0.14591936787124363,
#  'universe': 0.23757108153001857,
#  'beyond': 0.6309281505257376,
#  'time': 0.08233415344087902,
#  'mind': 0.2219670260550826,
#  'programmer': 0.3622727265255825,
#  'want': 0.08978740687577738,
#  'seen': 0.22343702242473878,
#  'superpower': 0.7137191918014835,
#  'while': 0.1305281222685282,
#  'very': 0.1639212988654175,
#  'keen': 1.370545283819546,
#  'being': 0.1135365441531746,
#  'g5': 2.9303490772066243,
#  'building': 0.3093773796794537,
#  'minimum': 0.3043308859376472,
#  'steel': 0.3910858505413341,
#  'section': 0.4417667451753891,
#  'used': 0.10809805971070566,
#  'epic': 0.6799808820841952,
#  'photos': 0.27531621164298087,
#  'taken': 0.27653945694388593,
#  'feet': 0.4008967888298903,
#  'parts': 0.3658855079116653,
#  'fall': 0.23745962429586154,
#  'asleep': 0.6267908721301076,
#  'muslims': 0.2863626622867901,
#  'shia': 0.907417077988208,
#  'sunni': 0.9926667180452633,
#  'much': 0.0800169214102413,
#  'served': 1.0856336362497538,
#  'liter': 1.3104919468875582,
#  'bottle': 0.6247525224324543,
#  'vodka': 0.7954384424890927,
#  'people': 0.06100734361724167,
#  'pay': 0.17593156496484186,
#  'netflix': 0.39309143215795195,
#  'stream': 0.3778568769751779,
#  'online': 0.10688929872580631,
#  'better': 0.09400480759944298,
#  'quality': 0.24287414608012753,
#  'euthanasia': 1.4651745386033121,
#  'morally': 0.933348498841593,
#  'permissible': 1.880372616390323,
#  'worth': 0.18084046919657754,
#  'loose': 0.5827492798484112,
#  'virginity': 0.6672698382491427,
#  'freshman': 0.5827492798484112,
#  'about': 0.06459018504728081,
#  'rbi': 0.43340447332716814,
#  'allowing': 0.9266577423345533,
#  'once': 0.2660814101799393,
#  'deposit': 0.47358831860845985,
#  'old': 0.12260062287028581,
#  'notes': 0.2243707374095275,
#  'bank': 0.1607546423282842,
#  'account': 0.13019641112931335,
#  'hill': 0.907417077988208,
#  'spot': 0.568475701904588,
#  'equal': 0.35992282458212127,
#  'distance': 0.311116166280531,
#  'bangalore': 0.19504725165904502,
#  'pune': 0.2662382515788698,
#  'make': 0.0726164480114537,
#  'myself': 0.18428150291438417,
#  'entire': 0.4424856500369242,
#  'book': 0.13045418959634436,
#  'become': 0.09730064409344155,
#  'chancellor': 2.741090567639092,
#  'university': 0.14040729303361893,
#  'if': 0.044478067028039976,
#  'trump': 0.12263129219481064,
#  'wins': 0.5215215296441298,
#  'nuclear': 0.29493706557219246,
#  'war': 0.14923371019764708,
#  'prevent': 0.30987119863648016,
#  'users': 0.2659248456414176,
#  'same': 0.13637435282673532,
#  'seeing': 0.44033938524000826,
#  'profile': 0.25843249709654464,
#  'osama': 1.1308876197530142,
#  'bin': 0.8172353122299327,
#  'laden': 1.1688049452325227,
#  'person': 0.11233836219763538,
#  'porn': 0.2659248456414176,
#  'video': 0.1622259510509826,
#  'sbi': 0.3358186211952271,
#  'transaction': 0.6129264841724495,
#  'id': 0.30742545243527164,
#  'good': 0.05843194785843699,
#  'studying': 0.23914814727765887,
#  'career': 0.15922182653893258,
#  'cybersecurity': 1.7336178933086726,
#  'components': 0.6017475554432504,
#  'fitness': 0.5145830183939063,
#  'implement': 0.506827825246843,
#  'rest': 0.35992282458212127,
#  'api': 0.38057857032782483,
#  'either': 0.4287404923563119,
#  'http': 1.182317590041242,
#  'status': 0.32850409002533776,
#  'creating': 0.4506325134321337,
#  'custom': 0.48646491161873173,
#  'field': 0.22325167438585145,
#  'by': 0.07166096788815539,
#  'returning': 1.0649530063154793,
#  '200': 0.43005767055128785,
#  'iupac': 1.520483475740529,
#  'name': 0.14226240751720953,
#  'chloride': 0.8722778270682666,
#  'similar': 0.23125185389273234,
#  'soylent': 2.9303490772066243,
#  'ensure': 0.6599770527411749,
#  'nutritionally': 2.3376098904650453,
#  'future': 0.16732173393062819,
#  'sociology': 0.6267908721301076,
#  'education': 0.2115584479933364,
#  'choose': 0.19991457617181757,
#  'right': 0.1555894046110632,
#  'decision': 0.3333264262993574,
#  'void': 1.096436227055637,
#  'p': 0.5946260317603485,
#  'c': 0.15225344226849855,
#  'take': 0.10051859143831879,
#  'mucinex': 2.741090567639092,
#  'blood': 0.24145658059033775,
#  'pressure': 0.2891371750234281,
#  'universities': 0.19762826992468538,
#  'phd': 0.2610562445370564,
#  'programs': 0.34776845369341053,
#  'image': 0.3191849259428655,
#  'processing': 0.44613357367823586,
#  'computer': 0.13282576072458008,
#  'vision': 0.453708538994104,
#  'favorite': 0.19529461669397002,
#  'moment': 0.3146835443960707,
#  'interesting': 0.19121302498672577,
#  'balloons': 1.4651745386033121,
#  'designed': 0.5414912561508309,
#  'built': 0.4008967888298903,
#  'macys': 1.9382437282240847,
#  'thanksgiving': 1.107567844699477,
#  'day': 0.11272955907113313,
#  'parade': 1.582569377099574,
#  'significance': 0.35799911853234506,
#  'set': 0.23624385839928935,
#  'honeywell': 1.4154930825216585,
#  'thermostat': 1.257698608361194,
#  'needs': 0.3738816502211536,
#  'power': 0.1780529658550765,
#  'laptop': 0.18020430808562876,
#  'gaming': 0.3610920409522281,
#  'editing': 0.5057483185361348,
#  'meaning': 0.17454396448971568,
#  'hindi': 0.2767155406656082,
#  'word': 0.16110132084680054,
#  'ब': 3.467235786617345,
#  'े': 2.2380910764905586,
#  'ी': 1.9382437282240847,
#  'data': 0.1333157858549815,
#  'structures': 0.48646491161873173,
#  'algorithms': 0.386683242911118,
#  'beginner': 0.34776845369341053,
#  'answers': 0.2304332606906148,
#  'written': 0.2885358492251676,
#  'women': 0.1334342010841199,
#  'empowerment': 1.652939805316576,
#  'makes': 0.17914285446665246,
#  'isis': 0.3833599367119556,
#  'attractive': 0.3361340920221406,
#  'youth': 0.6227339306534507,
#  'living': 0.19304172733761576,
#  'western': 0.3287993746602606,
#  'adding': 0.7495083746952517,
#  '12': 0.23690468167165005,
#  '14': 0.3696085767403132,
#  'equals': 1.1688049452325227,
#  'differentiate': 0.7019213677880002,
#  'between': 0.06563721489641222,
#  'human': 0.1665862502210078,
#  'animal': 0.3355040369377068,
#  'difference': 0.08053327601391252,
#  'watts': 1.2108112579750092,
#  'divorce': 0.5238974942437555,
#  'change': 0.13133092026225088,
#  'happens': 0.170077007978521,
#  'stock': 0.2244647540645689,
#  'options': 0.2558863020254702,
#  'quit': 0.38524842073526055,
#  'suffer': 0.6148509048705433,
#  'during': 0.1440685217189246,
#  'abortion': 0.7460303588301862,
#  'chefs': 1.329624228207088,
#  'write': 0.16421519654445138,
#  'menus': 2.3376098904650453,
#  'cooking': 0.5654438098765071,
#  'home': 0.16201328858107875,
#  'made': 0.14015469977592993,
#  'static': 0.6035682783800576,
#  'menu': 0.8360247854342987,
#  'three': 0.25602578761883565,
#  'cuisines': 2.3376098904650453,
#  'tips': 0.18443787248253998,
#  'writing': 0.22588933841336675,
#  'ieee': 1.6166070211617805,
#  'sat': 0.4666742494207965,
#  'requirements': 0.3910858505413341,
#  'aroused': 1.329624228207088,
#  'movie': 0.12937807234186222,
#  'scene': 0.42549977701635033,
#  'slave': 0.9012650268642673,
#  'whipped': 1.370545283819546,
#  'excited': 0.9266577423345533,
#  'red': 0.255330630789811,
#  'strips': 1.4154930825216585,
#  'normal': 0.2058150746695691,
#  'distinguishes': 2.072069703736546,
#  'litigation': 2.5843249709654463,
#  'forms': 0.5191776007937161,
#  'legal': 0.21981543705244974,
#  'intervention': 1.6166070211617805,
#  'deeds': 1.582569377099574,
#  'inherently': 1.4154930825216585,
#  'selfish': 0.7714498373096909,
#  'horror': 0.5595227691226397,
#  'hollywood': 0.3380457705189927,
#  'movies': 0.15284403192669396,
#  'watch': 0.17744567337196052,
#  'case': 0.2804927881220508,
#  'plant': 0.37607452327806457,
#  'synchronous': 0.9201088423062463,
#  'generator': 0.5999432108853514,
#  'asynchronous': 1.7786544293221684,
#  'preferred': 0.6623813486918926,
#  'us': 0.08954752558453956,
#  'bad': 0.1371402678513241,
#  'over': 0.1333946942879663,
#  'coming': 0.28519779239125326,
#  'scope': 0.265768557149727,
#  'material': 0.3591496275031095,
#  'science': 0.13488024910290963,
#  'engineering': 0.10887334678383519,
#  'practising': 2.3376098904650453,
#  'financial': 0.2767155406656082,
#  'planner': 1.4920607176603724,
#  'been': 0.1224170889008103,
#  'able': 0.1922093907898513,
#  'terms': 0.22043651116988355,
#  'advisory': 1.392475400836756,
#  'fee': 0.4267872225516286,
#  'alone': 0.30132792707856043,
#  'company': 0.12263129219481064,
#  'stats': 0.9136968558796974,
#  'prove': 0.31494307726030657,
#  'activities': 0.4198471303977506,
#  'combat': 0.5946260317603485,
#  'achievement': 1.1190455382452793,
#  'gap': 0.45293363059077046,
#  'promote': 0.39512818896439894,
#  'admissions': 0.6072598619020532,
#  'pronounce': 0.5860698154413249,
#  'paid': 0.26878604409455487,
#  'amount': 0.27885512567020987,
#  'taking': 0.24854896473845772,
#  'parents': 0.18710406847608327,
#  'tu': 1.182317590041242,
#  'convocation': 2.5843249709654463,
#  'them': 0.11549755350060427,
#  'opportunities': 0.3233214042323561,
#  'sweden': 0.5928848097740562,
#  'medicine': 0.3730151794150931,
#  'automobile': 0.6091312372531316,
#  'projects': 0.29841214353207446,
#  'related': 0.24665499024046994,
#  'design': 0.1895485245418892,
#  'part': 0.21404321281278582,
#  'basic': 0.2631531155277884,
#  'knowledge': 0.27462446127437085,
#  'everyone': 0.2722437708687175,
#  'known': 0.2665527682290901,
#  'startup': 0.2040963383192244,
#  'venture': 0.4798970994428283,
#  'capital': 0.2936648652539975,
#  'firms': 0.4608665213812296,
#  'colleges': 0.23869435531797462,
#  'usa': 0.16141525681361824,
#  'aerospace': 0.6247525224324543,
#  'items': 0.47898038972431645,
#  'wool': 1.439691298328485,
#  'itchy': 0.8778515440171724,
#  'others': 0.22465314247713758,
#  'soft': 0.568475701904588,
#  'obese': 1.2921624854827232,
#  'eat': 0.17036419647297996,
#  'lot': 0.23418717169576414,
#  'than': 0.08816462682093713,
#  'average': 0.17194901382284314,
#  'wireless': 0.492314399283563,
#  'internet': 0.1887603775750207,
#  'desktop': 0.49735357255345747,
#  'song': 0.1884255968606019,
#  'cancer': 0.32588184249052243,
#  'cured': 0.6879652756298394,
#  'healing': 0.984628798567126,
#  'kind': 0.188816348036614,
#  'pens': 1.392475400836756,
#  'men': 0.1506924202329969,
#  'dont': 0.10161775103396974,
#  'divorced': 0.961638185597889,
#  'woman': 0.19461661534700508,
#  'seriously': 0.6351484527628009,
#  'trust': 0.3756328619122092,
#  'chegg': 2.5843249709654463,
#  'anybody': 0.4144139407473092,
#  'got': 0.1717379556681503,
#  '5': 0.1555894046110632,
#  'gb': 0.4808190927989445,
#  'ram': 0.34196906361091506,
#  'core': 0.31212301734710407,
#  'i3': 0.7460303588301862,
#  'i5': 0.6072598619020532,
#  'processor': 0.4584430171787984,
#  'android': 0.13494152581498395,
#  'studio': 0.45527036302429774,
#  'changed': 0.2891371750234281,
#  'deeply': 0.7325872693016561,
#  'held': 0.5454974113069413,
#  'opinion': 0.3136517922928397,
#  'depersonalization': 2.741090567639092,
#  'disorder': 0.35685959590074173,
#  'wifi': 0.2597344322738939,
#  'running': 0.28873587410134055,
#  'hotspot': 0.8835334903507782,
#  'lg': 0.6438495219354844,
#  'g3': 0.933348498841593,
#  'app': 0.12548947393771426,
#  'expectations': 0.8561728512511433,
#  'partners': 0.6072598619020532,
#  'sex': 0.1375280965629993,
#  'story': 0.2243707374095275,
#  'experiments': 0.8835334903507782,
#  'truth': 0.413234951329144,
#  'mahatma': 0.7954384424890927,
#  'gandhi': 0.40525449064235225,
#  'beautiful': 0.2597344322738939,
#  'scandinavian': 1.0180154798633365,
#  'country': 0.13502335816077995,
#  'ebook': 0.8127326040674668,
#  'french': 0.2830986165043317,
#  'something': 0.18402176846124926,
#  'academy': 0.4845609320560212,
#  'awards': 0.8778515440171724,
#  'come': 0.1578627728694866,
#  'called': 0.21772522694430596,
#  'oscars': 1.582569377099574,
#  'percy': 1.4651745386033121,
#  'jackson': 0.5894477674232309,
#  'suck': 0.7495083746952517,
#  'easy': 0.2563054444882452,
#  'delhi': 0.18079129435700173,
#  'bike': 0.32969002922549123,
#  'hyderabad': 0.2616502299341649,
#  'muhammed': 2.3376098904650453,
#  'narcissist': 0.6247525224324543,
#  'receive': 0.3638651417897731,
#  'convenient': 1.520483475740529,
#  'revelations': 1.7336178933086726,
#  'his': 0.11710694278465603,
#  'benefit': 0.3925871453151092,
#  'force': 0.23701535894079057,
#  'wolf': 0.696237700418378,
#  'bite': 0.6054056289875046,
#  'slack': 1.1431137871772794,
#  'tool': 0.3361340920221406,
#  'team': 0.25327865031721514,
#  'communication': 0.326459135843809,
#  'pain': 0.27885512567020987,
#  'points': 0.42108379619955566,
#  'solving': 0.5715568935886397,
#  'share': 0.2514074367713348,
#  'files': 0.3033973534132969,
#  'intermediate': 0.8952364305962234,
#  'value': 0.21054189809977783,
#  'theorem': 0.7460303588301862,
#  'meant': 0.3595356024962835,
#  'mainstream': 0.9266577423345533,
#  'culture': 0.20559785553287932,
#  'would': 0.06064604562665163,
#  'noteworthy': 2.150288352756439,
#  'example': 0.2999716054426757,
#  'causes': 0.21729722333217047,
#  'eye': 0.30527308907718786,
#  'twitch': 1.6166070211617805,
#  'santa': 0.7358798129444096,
#  'live': 0.13516692370708777,
#  'north': 0.25900871296706823,
#  'pole': 0.775297491289634,
#  'mandela': 1.4920607176603724,
#  'effect': 0.25602578761883565,
#  'moved': 0.6394545932830167,
#  'him': 0.15666572258185496,
#  'finland': 0.8172353122299327,
#  'main': 0.20870306901071856,
#  'cologne': 1.7336178933086726,
#  'noam': 1.107567844699477,
#  'chomsky': 1.1190455382452793,
#  'russell': 1.370545283819546,
#  '23': 0.3946160329630597,
#  'year': 0.1033546263157964,
#  'boy': 0.27008767903947795,
#  '58': 0.984628798567126,
#  'kgs': 0.7792032968216817,
#  'weight': 0.16514391787654564,
#  'height': 0.2804927881220508,
#  '168': 2.150288352756439,
#  'cms': 0.8360247854342987,
#  'chance': 0.2795794259179652,
#  'increase': 0.18650758970754655,
#  'yes': 0.2763637089395162,
#  'habits': 0.5123310031303581,
#  'follow': 0.24816667951131582,
#  'calculate': 0.2604662861681878,
#  'required': 0.223344290724366,
#  'length': 0.4150072323048473,
#  'water': 0.1442679246125838,
#  'filled': 0.6438495219354844,
#  'pipe': 0.9266577423345533,
#  'gravity': 0.32850409002533776,
#  'fed': 0.8722778270682666,
#  'into': 0.10260968566135538,
#  'container': 1.0856336362497538,
#  'keep': 0.1827393711759395,
#  'motivated': 0.5227054619955679,
#  'hard': 0.179719496047418,
#  'times': 0.21586067140024454,
#  'drinking': 0.3390139226795184,
#  'redbull': 3.165138754199148,
#  'health': 0.21729722333217047,
#  'devices': 0.37087508614013265,
#  'phone': 0.12181120995782688,
#  'under': 0.15756907443302015,
#  '12k': 1.652939805316576,
#  'loves': 0.3658855079116653,
#  'hate': 0.21789713792801316,
#  'cure': 0.3377248916896609,
#  'jet': 0.5468526864673131,
#  '7': 0.20765241761733538,
#  'holding': 0.7198456491642425,
#  'up': 0.10124449019081123,
#  'against': 0.18208303204057127,
#  'scratches': 1.6918378285448161,
#  'convert': 0.25814582757170984,
#  'kolkata': 0.3956423442748935,
#  'registration': 0.5762740868756984,
#  'privately': 1.370545283819546,
#  'owned': 0.8614416569884822,
#  'commercial': 0.36266886959257144,
#  'airbnb': 0.5894477674232309,
#  'property': 0.3377248916896609,
#  'expensive': 0.346377374303146,
#  'sent': 0.3383675657089632,
#  'message': 0.27410905676390923,
#  'whatsapp': 0.19899056856246125,
#  'says': 0.23779446764569073,
#  'delivered': 0.5894477674232309,
#  'early': 0.30815308766007715,
#  'morning': 0.3358186211952271,
#  'rom': 0.7325872693016561,
#  'kilometers': 1.6166070211617805,
#  'away': 0.25546920916136473,
#  'connection': 0.4080513112050705,
#  'requirement': 0.696237700418378,
#  'hit': 0.3838294530382053,
#  'big': 0.1694664627222084,
#  'shots': 0.961638185597889,
#  'am': 0.07550325591669041,
#  'female': 0.2518049191330028,
#  'capricorn': 1.370545283819546,
#  'sun': 0.2869504754177378,
#  'sign': 0.3183765204423394,
#  'moon': 0.2770687195466376,
#  'libra': 1.241469559299247,
#  'rising': 0.791284688549787,
#  'star': 0.24064104336827472,
#  'guess': 0.9471766372169197,
#  'etg': 1.582569377099574,
#  'testing': 0.35648216629127594,
#  'examples': 0.1330211215607416,
#  'monopolies': 3.165138754199148,
#  'children': 0.23053510965058924,
#  'stack': 0.4903411873379596,
#  'overflow': 1.3496196995203253,
#  'lack': 0.4845609320560212,
#  'pro': 0.2836665180109002,
#  'bono': 2.9303490772066243,
#  'lawyer': 0.492314399283563,
#  'two': 0.14180953114932335,
#  'accounts': 0.3433074995039961,
#  'painting': 0.506827825246843,
#  'means': 0.348118850209189,
#  'workouts': 1.000904757373714,
#  'muscles': 0.5552020653179645,
#  'america': 0.19931909869957548,
#  'attacked': 0.7676589060764106,
#  '10': 0.14749521667897475,
#  'million': 0.326459135843809,
#  'troops': 0.9926667180452633,
#  'could': 0.11134919280926077,
#  'handle': 0.38716509137582367,
#  'long': 0.11977367280374004,
#  'arrive': 0.5928848097740562,
#  'alternative': 0.4242239127438629,
#  'question': 0.15842204671439344,
#  'answer': 0.18417747722000144,
#  'websites': 0.21428834732275887,
#  'observe': 1.036034851868273,
#  'planets': 0.4417667451753891,
#  'radio': 0.4446636073305421,
#  'telescopes': 1.520483475740529,
#  'theory': 0.22932175854327982,
#  'explains': 1.4651745386033121,
#  'demonic': 2.001809514747428,
#  'possessions': 2.150288352756439,
#  'invention': 0.7107140450149502,
#  'making': 0.18376312916482848,
#  'interested': 0.27903567287311365,
#  'religion': 0.26179936088382455,
#  'wear': 0.2071330075048432,
#  'sports': 0.33740492488008134,
#  'bra': 0.6934471573234691,
#  'gym': 0.37475418734762583,
#  'personality': 0.2973130158801742,
#  'types': 0.24728149617790596,
#  'disorders': 0.826469902658288,
#  'unable': 0.4649925349443331,
#  'feel': 0.10219878076873938,
#  'intimacy': 1.7336178933086726,
#  'impulse': 1.520483475740529,
#  'limit': 0.33740492488008134,
#  'socializing': 2.150288352756439,
#  'personal': 0.2598803095290193,
#  'relationships': 0.4144139407473092,
#  'atmosphere': 0.6438495219354844,
#  'sky': 0.5036098382660056,
#  'appear': 0.36031130049075494,
#  'coaching': 0.23228746970443243,
#  'medical': 0.215111586417932,
#  'nagpur': 0.8409281986555794,
#  'recommend': 0.3622727265255825,
#  'ca': 0.25828904302104666,
#  'ipcc': 0.6906899012455153,
#  'both': 0.20283517482208577,
#  'groups': 0.4091863657236766,
#  'pursue': 0.29863343547463467,
#  'journalism': 0.696237700418378,
#  'btech': 0.25127536035729625,
#  'degree': 0.19179723968438855,
#  'debt': 0.4584430171787984,
#  '’': 0.1519023577683553,
#  's': 0.18253666521096923,
#  'creative': 0.3642665375453473,
#  'honestly': 1.329624228207088,
#  'finding': 0.44613357367823586,
#  'cheated': 0.5414912561508309,
#  'rarest': 1.4920607176603724,
#  'pictures': 0.30987119863648016,
#  'cook': 0.3946160329630597,
#  'chicken': 0.3833599367119556,
#  'breast': 0.6372906121419994,
#  'oven': 0.5580713457462273,
#  'indians': 0.22724371917344618,
#  'spend': 0.2877398867453771,
#  'marriage': 0.24407471763763447,
#  'rather': 0.320546061865963,
#  'americans': 0.25743330667765213,
#  'europeans': 0.7229686384442364,
#  'apple': 0.2128300353893411,
#  'chip': 0.7792032968216817,
#  'embedded': 0.5495938198653355,
#  'rupees': 0.39512818896439894,
#  '2000': 0.3470708231940928,
#  'feeling': 0.28873587410134055,
#  'versus': 0.5654438098765071,
#  'measuring': 0.9767830257355414,
#  'progress': 0.6722681840442812,
#  'actually': 0.1961678643048231,
#  'contact': 0.2683027604358275,
#  'customer': 0.367114002161399,
#  'support': 0.20044839441494516,
#  'mcom': 1.4651745386033121,
#  'doing': 0.15618813060811357,
#  'srcc': 1.3496196995203253,
#  'dangers': 0.9401863081951615,
#  'valium': 2.451705936689798,
#  'percocet': 2.3376098904650453,
#  'glue': 0.803946047513033,
#  'shoe': 0.7358798129444096,
#  'repair': 0.47447435926822884,
#  'percentage': 0.2817866661699515,
#  '62': 1.274581224283999,
#  'join': 0.20146093694675038,
#  'niit': 2.001809514747428,
#  'provide': 0.2850050260343927,
#  'me': 0.06948103227699923,
#  'mncs': 1.257698608361194,
#  'unhealthy': 0.6799808820841952,
#  'hillary': 0.18428150291438417,
#  'supporters': 0.4933099804809399,
#  'terribly': 2.150288352756439,
#  'ill': 0.506827825246843,
#  'amazon': 0.21763942389587265,
#  ...}

# %%
negative_sampling_prob_dict = get_negative_sampling_prob(word_count_dict)
assert negative_sampling_prob_dict.keys() == negative_sampling_prob_dict.keys()
assert np.allclose(sum(negative_sampling_prob_dict.values()), 1)
# Out:
# C:\Users\VIKTOR\AppData\Local\Temp\ipykernel_7304\962603389.py:25: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   Z = np.sum((word_count_dict[word] / sum_words) ** 0.75 for word in word_count_dict.keys())

# %%
keep_prob_array = np.array(
    [keep_prob_dict[index_to_word[idx]] for idx in range(len(word_to_index))]
)
negative_sampling_prob_array = np.array(
    [
        negative_sampling_prob_dict[index_to_word[idx]]
        for idx in range(len(word_to_index))
    ]
)

# %%
negative_sampling_prob_array
# Out:
# array([6.68210018e-05, 1.56848822e-05, 5.01697928e-06, ...,
#        1.22437557e-05, 3.89803990e-06, 3.89803990e-06])

# %% [markdown]
# Если все прошло успешно, функция ниже поможет вам с генерацией подвыборок (батчей).

# %%
def generate_batch_with_neg_samples(
    context_pairs,
    batch_size,
    keep_prob_array,
    word_to_index,
    num_negatives,
    negative_sampling_prob_array,
):
    batch = []
    neg_samples = []

    while len(batch) < batch_size:
        center, context = random.choice(context_pairs)
        if random.random() < keep_prob_array[center]:
            batch.append((center, context))
            neg_sample = np.random.choice(
                range(len(negative_sampling_prob_array)),
                size=num_negatives,
                p=negative_sampling_prob_array,
            )
            neg_samples.append(neg_sample)
    batch = np.array(batch)
    neg_samples = np.vstack(neg_samples)
    return batch, neg_samples

# %%
batch_size = 4
num_negatives = 15
batch, neg_samples = generate_batch_with_neg_samples(
    context_pairs,
    batch_size,
    keep_prob_array,
    word_to_index,
    num_negatives,
    negative_sampling_prob_array,
)

# %%
batch, neg_samples
# Out:
# (array([[ 6753, 23030],
#         [ 8143, 12359],
#         [ 9930, 27603],
#         [    1,  4232]]),
#  array([[10098, 27393, 18685, 13071,  3928, 20239, 25599, 15005, 22360,
#          26583, 18770, 11617, 12362, 24337,   923],
#         [26887, 21211, 14155, 26824,  6080, 19071, 14434,   868, 26359,
#          17351, 20502, 27276, 20239, 10275,  1255],
#         [ 9551, 16879, 27603, 27603,  4871, 19717, 20528,  7894, 23879,
#           3322,  5444,   192,  8954,  9397, 27350],
#         [19427,  1571, 27624,  4442,  9933, 16258, 11517,    16,  2303,
#          11167, 26519, 13765,  5862,  5710,   428]]))

# %% [markdown]
# Наконец, время реализовать модель. Обращаем ваше внимание, использование линейных слоев (`nn.Linear`) далеко не всегда оправданно!
#
# Напомним, что в случае negative sampling решается задача максимизации следующего функционала:
#
# $$
# \mathcal{L} = \log \sigma({\mathbf{v}'_{w_O}}^\top \mathbf{v}_{w_I}) + \sum_{i=1}^{k} \mathbb{E}_{w_i \sim P_n(w)} \left[ \log \sigma({-\mathbf{v}'_{w_i}}^\top \mathbf{v}_{w_I}) \right],
# $$
#
# где:
# - $\mathbf{v}_{w_I}$ – вектор центрального слова $w_I$,
# - $\mathbf{v}'_{w_O}$ – вектор слова из контекста $w_O$,
# - $k$ – число negative samplesЮ,
# - $P_n(w)$ – распределение negative samples, заданное выше,
# - $\sigma$ – сигмоида.

# %%
import torch
import torch.nn as nn
import torch.nn.functional as F

class SkipGramModelWithNegSampling(nn.Module):
    def __init__(self, vocab_size, embedding_dim):
        super().__init__()
        # Embedding for center (input) words
        self.center_embeddings = nn.Embedding(vocab_size, embedding_dim)
        # Embedding for context (output) words
        self.context_embeddings = nn.Embedding(vocab_size, embedding_dim)
        
        # Initialize embeddings
        #nn.init.uniform_(self.center_embeddings.weight, -0.5 / embedding_dim, 0.5 / embedding_dim)
        #nn.init.uniform_(self.context_embeddings.weight, -0.5 / embedding_dim, 0.5 / embedding_dim)

    def forward(self, center_words, pos_context_words, neg_context_words):
        # Center word embeddings: (batch_size, embedding_dim)
        v_center = self.center_embeddings(center_words)  # (batch_size, embedding_dim)
        v_pos_context = self.context_embeddings(pos_context_words)  # (batch_size, embedding_dim)
        v_neg_context = self.context_embeddings(neg_context_words)  # (batch_size, k, embedding_dim)

        # Положительные скоры
        pos_scores = torch.sum(v_center * v_pos_context, dim=1)  # скалярное произведение
        pos_scores = F.logsigmoid(pos_scores)  # логарифм сигмоиды

        # Отрицательные скоры
        neg_scores = torch.bmm(v_neg_context, v_center.unsqueeze(2)).squeeze(2)  # (batch_size, k)
        neg_scores = F.logsigmoid(-neg_scores)  # логарифм сигмоиды с отрицанием
        neg_scores = torch.sum(neg_scores, dim=1)

        return pos_scores, neg_scores

# %%
device = torch.device("cpu")

# %%
vocab_size = len(word_to_index)
embedding_dim = 32
num_negatives = 15

model = SkipGramModelWithNegSampling(vocab_size, embedding_dim).to(device)
optimizer = optim.Adam(model.parameters(), lr=0.05)
lr_scheduler = ReduceLROnPlateau(optimizer, factor=0.5, patience=150)
criterion = nn.BCEWithLogitsLoss()

# %%
params_counter = 0
for weights in model.parameters():
    params_counter += weights.shape.numel()
assert params_counter == len(word_to_index) * embedding_dim * 2

# %%
def train_skipgram_with_neg_sampling(
    model,
    context_pairs,
    keep_prob_array,
    word_to_index,
    batch_size,
    num_negatives,
    negative_sampling_prob_array,
    steps,
    optimizer=optimizer,
    lr_scheduler=lr_scheduler,
    device=device,
):
    pos_labels = torch.ones(batch_size).to(device)
    neg_labels = torch.zeros(batch_size, num_negatives).to(device)
    loss_history = []
    for step in tqdma(range(steps)):
        batch, neg_samples = generate_batch_with_neg_samples(
            context_pairs,
            batch_size,
            keep_prob_array,
            word_to_index,
            num_negatives,
            negative_sampling_prob_array,
        )
        center_words = torch.tensor([pair[0] for pair in batch], dtype=torch.long).to(
            device
        )
        pos_context_words = torch.tensor(
            [pair[1] for pair in batch], dtype=torch.long
        ).to(device)
        neg_context_words = torch.tensor(neg_samples, dtype=torch.long).to(device)

        optimizer.zero_grad()
        pos_scores, neg_scores = model(
            center_words, pos_context_words, neg_context_words
        )

        loss_pos = criterion(pos_scores, pos_labels)
        loss_neg = criterion(neg_scores, neg_labels)

        loss = loss_pos + loss_neg
        loss.backward()
        optimizer.step()

        loss_history.append(loss.item())
        lr_scheduler.step(loss_history[-1])

        if step % 100 == 0:
            print(
                f"Step {step}, Loss: {np.mean(loss_history[-100:])}, learning rate: {lr_scheduler._last_lr}"
            )

# %%
steps = 2500
batch_size = 5000
train_skipgram_with_neg_sampling(
    model,
    context_pairs,
    keep_prob_array,
    word_to_index,
    batch_size,
    num_negatives,
    negative_sampling_prob_array,
    steps,
)
# Out:
#   0%|          | 0/2500 [00:00<?, ?it/s]
# Step 0, Loss: 1.5040770769119263, learning rate: [0.05]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[28], line 3
#       1 steps = 2500
#       2 batch_size = 5000
# ----> 3 train_skipgram_with_neg_sampling(
#       4     model,
#       5     context_pairs,
#       6     keep_prob_array,
#       7     word_to_index,
#       8     batch_size,
#       9     num_negatives,
#      10     negative_sampling_prob_array,
#      11     steps,
#      12 )
#
# Cell In[27], line 18, in train_skipgram_with_neg_sampling(model, context_pairs, keep_prob_array, word_to_index, batch_size, num_negatives, negative_sampling_prob_array, steps, optimizer, lr_scheduler, device)
#      16 loss_history = []
#      17 for step in tqdma(range(steps)):
# ---> 18     batch, neg_samples = generate_batch_with_neg_samples(
#      19         context_pairs,
#      20         batch_size,
#      21         keep_prob_array,
#      22         word_to_index,
#      23         num_negatives,
#      24         negative_sampling_prob_array,
#      25     )
#      26     center_words = torch.tensor([pair[0] for pair in batch], dtype=torch.long).to(
#      27         device
#      28     )
#      29     pos_context_words = torch.tensor(
#      30         [pair[1] for pair in batch], dtype=torch.long
#      31     ).to(device)
#
# Cell In[21], line 16, in generate_batch_with_neg_samples(context_pairs, batch_size, keep_prob_array, word_to_index, num_negatives, negative_sampling_prob_array)
#      14     if random.random() < keep_prob_array[center]:
#      15         batch.append((center, context))
# ---> 16         neg_sample = np.random.choice(
#      17             range(len(negative_sampling_prob_array)),
#      18             size=num_negatives,
#      19             p=negative_sampling_prob_array,
#      20         )
#      21         neg_samples.append(neg_sample)
#      22 batch = np.array(batch)
#
# File numpy\\random\\mtrand.pyx:981, in numpy.random.mtrand.RandomState.choice()
#
# File c:\Users\VIKTOR\AppData\Local\Programs\Python\Python310\lib\site-packages\numpy\core\fromnumeric.py:2974, in _prod_dispatcher(a, axis, dtype, out, keepdims, initial, where)
#    2960     """
#    2961     Return the minimum of an array or minimum along an axis.
#    2962
#    (...)
#    2968     ndarray.min : equivalent method
#    2969     """
#    2970     return _wrapreduction(a, np.minimum, 'min', axis, None, out,
#    2971                           keepdims=keepdims, initial=initial, where=where)
# -> 2974 def _prod_dispatcher(a, axis=None, dtype=None, out=None, keepdims=None,
#    2975                      initial=None, where=None):
#    2976     return (a, out)
#    2979 @array_function_dispatch(_prod_dispatcher)
#    2980 def prod(a, axis=None, dtype=None, out=None, keepdims=np._NoValue,
#    2981          initial=np._NoValue, where=np._NoValue):
#
# KeyboardInterrupt:

# %% [markdown]
# Наконец, используйте полученную матрицу весов в качестве матрицы в векторными представлениями слов. Рекомендуем использовать для сдачи матрицу, которая отвечала за слова из контекста (т.е. декодера).

# %%
_model_parameters = model.parameters()
embedding_matrix_center = next(
    _model_parameters
).detach()  # Assuming that first matrix was for central word
embedding_matrix_context = next(
    _model_parameters
).detach()  # Assuming that second matrix was for context word

# %%
def get_word_vector(word, embedding_matrix, word_to_index=word_to_index):
    return embedding_matrix[word_to_index[word]]

# %% [markdown]
# Простые проверки:

# %%
similarity_1 = F.cosine_similarity(
    get_word_vector("iphone", embedding_matrix_context)[None, :],
    get_word_vector("apple", embedding_matrix_context)[None, :],
)
similarity_2 = F.cosine_similarity(
    get_word_vector("iphone", embedding_matrix_context)[None, :],
    get_word_vector("dell", embedding_matrix_context)[None, :],
)
assert similarity_1 > similarity_2

# %%
similarity_1 = F.cosine_similarity(
    get_word_vector("windows", embedding_matrix_context)[None, :],
    get_word_vector("laptop", embedding_matrix_context)[None, :],
)
similarity_2 = F.cosine_similarity(
    get_word_vector("windows", embedding_matrix_context)[None, :],
    get_word_vector("macbook", embedding_matrix_context)[None, :],
)
assert similarity_1 > similarity_2

# %% [markdown]
# Наконец, взглянем на ближайшие по косинусной мере слова. Функция реализована ниже.

# %%
def find_nearest(word, embedding_matrix, word_to_index=word_to_index, k=10):
    word_vector = get_word_vector(word, embedding_matrix)[None, :]
    dists = F.cosine_similarity(embedding_matrix, word_vector)
    index_sorted = torch.argsort(dists)
    top_k = index_sorted[-k:]
    return [(index_to_word[x], dists[x].item()) for x in top_k.numpy()]

# %%
find_nearest("python", embedding_matrix_context, k=10)
# Out:
# [('hierarchy', 0.9806427359580994),
#  ('debbie', 0.9806483387947083),
#  ('mandated', 0.9807882905006409),
#  ('weaker', 0.980898380279541),
#  ('swamy', 0.9809061288833618),
#  ('hipmunk', 0.980941116809845),
#  ('ugg', 0.9815243482589722),
#  ('compute', 0.9817937612533569),
#  ('linking', 0.982943058013916),
#  ('python', 1.0)]

# %% [markdown]
# Также вы можете визуально проверить, как представлены в латентном пространстве часто встречающиеся слова.

# %%
top_k = 5000
_top_words = sorted([x for x in word_count_dict.items()], key=lambda x: x[1])[
    -top_k - 100 : -100
]  # ignoring 100 most frequent words
top_words = [x[0] for x in _top_words]
del _top_words

# %%
word_embeddings = torch.cat(
    [embedding_matrix_context[word_to_index[x]][None, :] for x in top_words], dim=0
).numpy()

# %%
import bokeh.models as bm
import bokeh.plotting as pl
from bokeh.io import output_notebook

output_notebook()


def draw_vectors(
    x,
    y,
    radius=10,
    alpha=0.25,
    color="blue",
    width=600,
    height=400,
    show=True,
    **kwargs,
):
    """draws an interactive plot for data points with auxilirary info on hover"""
    if isinstance(color, str):
        color = [color] * len(x)
    data_source = bm.ColumnDataSource({"x": x, "y": y, "color": color, **kwargs})

    fig = pl.figure(active_scroll="wheel_zoom", width=width, height=height)
    fig.scatter("x", "y", size=radius, color="color", alpha=alpha, source=data_source)

    fig.add_tools(bm.HoverTool(tooltips=[(key, "@" + key) for key in kwargs.keys()]))
    if show:
        pl.show(fig)
    return fig
# Out:
#     <style>
#         .bk-notebook-logo {
#             display: block;
#             width: 20px;
#             height: 20px;
#             background-image: url(data:image/png;base64,...);
#         }
#     </style>
#     <div>
#         <a href="https://bokeh.org" target="_blank" class="bk-notebook-logo"></a>
#         <span id="b7b0d674-715e-468b-8ae8-50b8534bfb3f">Loading BokehJS ...</span>
#     </div>

# %%
embedding = umap.UMAP(n_neighbors=5).fit_transform(word_embeddings)

# %%
draw_vectors(embedding[:, 0], embedding[:, 1], token=top_words)
# Out:
#   <div id="c897c8ff-81bb-4f6b-aae4-4bc828ae06eb" data-root-id="p1055" style="display: contents;"></div>
# figure(id='p1055', ...)

# %% [markdown]
# Для сдачи задания необходимо загрузить функции `subsample_frequent_words` и `get_negative_sampling_prob`, а также сгенерировать файл для посылки ниже и приложить в соответствующую задачу. Успехов!

# %%
# do not change the code in the block below
# __________start of block__________
import os
import json

assert os.path.exists(
    "words_subset.txt"
), "Please, download `words_subset.txt` and place it in the working directory"

with open("words_subset.txt") as iofile:
    selected_words = iofile.read().split("\n")


def get_matrix_for_selected_words(selected_words, embedding_matrix, word_to_index):
    word_vectors = []
    for word in selected_words:
        index = word_to_index.get(word, None)
        vector = [0.0] * embedding_matrix.shape[1]
        if index is not None:
            vector = embedding_matrix[index].numpy().tolist()
        word_vectors.append(vector)
    return word_vectors


word_vectors = get_matrix_for_selected_words(
    selected_words, embedding_matrix_context, word_to_index
)

with open("submission_dict.json", "w") as iofile:
    json.dump(word_vectors, iofile)
print("File saved to `submission_dict.json`")
# __________end of block__________
